# %%
from pathlib import Path
import json

import numpy as np
from rich import print as rprint

from bin.experiment_utils import (
    analyze_data,
    execute_rand_experiments_tsp,
    execute_rand_experiments_vrp,
)

# %%
rng = np.random.default_rng()

# %%
execute_rand_experiments_tsp(n=10, rng=rng)
# Out:
# Output()

# %%
analyzed_tsp = analyze_data(Path("data/experiments/runs/tsp/"))
rprint(analyzed_tsp)
save_path = Path("data/experiments/analyzed_tsp.json")
with save_path.open("r") as f:
    json.dump(analyzed_tsp, f)
# Out:
# Output()
# {
#     'by_destination_n': {
#         16: {
#             'mean_exec_t': 2.173060941696167,
#             'mean_cost_improvement': 0.4742227681723289,
#             'mean_iters': 304.0
#         },
#         25: {
#             'mean_exec_t': 2.375994920730591,
#             'mean_cost_improvement': 0.46621138160017567,
#             'mean_iters': 262.0
#         },
#         9: {
#             'mean_exec_t': 1.9306821823120117,
#             'mean_cost_improvement': 0.3044828216821592,
#             'mean_iters': 317.5
#         }
#     },
#     'by_population_size': {
#         70: {
#             'mean_exec_t': 2.2545133531093597,
#             'mean_cost_improvement': 0.39159693062182077,
#             'mean_iters': 276.5
#         },
#         40: {
#             'mean_exec_t': 2.136228561401367,
#             'mean_cost_improvement': 0.2901208243088194,
#             'mean_iters': 296.0
#         },
#         20: {
#             'mean_exec_t': 0.5192151864369711,
#             'mean_cost_improvement': 0.17653973607955728,
#             'mean_iters': 118.0
#         },
#         10: {
#             'mean_exec_t': 0.2895205020904541,
#             'mean_cost_improvement': 0.13061757807287738,
#             'mean_iters': 124.25
#         },
#         80: {
#             'mean_exec_t': 0.5874102115631104,
#             'mean_cost_improvement': 0.09750912284335934,
#             'mean_iters': 42.2
#         },
#         30: {
#             'mean_exec_t': 0.6008700529734293,
#             'mean_cost_improvement': 0.14152234576928469,
#             'mean_iters': 110.0
#         }
#     },
#     'by_map': {
#         'data\\environments\\map_2021-12-15_09-07-17_tsp.json': {
#             'mean_exec_t': 2.173060941696167,
#             'mean_cost_improvement': 0.4742227681723289,
#             'mean_iters': 304.0,
#             'best_solution': [0, 4, 8, 9, 13, 12, 14, 15, 11, 10, 6, 2, 3, 7, 5, 1, 0],
#             'min_cost': 15.246722100079431,
#             'min_cost_mean': 15.88364715303367,
#             'min_cost_stddev': 0.9925605727060798
#         },
#         'data\\environments\\map_2021-12-15_09-11-04_tsp.json': {
#             'mean_exec_t': 2.375994920730591,
#             'mean_cost_improvement': 0.46621138160017567,
#             'mean_iters': 262.0,
#             'best_solution': [
#                 0,
#                 5,
#                 1,
#                 2,
#                 14,
#                 13,
#                 12,
#                 11,
#                 6,
#                 7,
#                 8,
#                 3,
#                 4,
#                 9,
#                 10,
#                 15,
#                 20,
#                 21,
#                 17,
#                 22,
#                 23,
#                 24,
#                 19,
#                 18,
#                 16,
#                 0
#             ],
#             'min_cost': 26.581457443762755,
#             'min_cost_mean': 28.153021694761453,
#             'min_cost_stddev': 2.559461550555706
#         },
#         'data\\environments\\map_2021-12-15_08-57-55_tsp.json': {
#             'mean_exec_t': 1.9306821823120117,
#             'mean_cost_improvement': 0.3044828216821592,
#             'mean_iters': 317.5,
#             'best_solution': [0, 4, 3, 6, 7, 8, 1, 2, 5, 0],
#             'min_cost': 12.517862305615052,
#             'min_cost_mean': 12.517862305615052,
#             'min_cost_stddev': 0.0
#         }
#     }
# }

# %%
execute_rand_experiments_vrp(n=10, salesmen_n=3, rng=rng)
# Out:
# Output()

# %%
analyzed_vrp = analyze_data(Path("data/experiments/runs/vrp/"))
rprint(analyzed_vrp)
save_path = Path("data/experiments/analyzed_vrp.json")
with save_path.open("r") as f:
    json.dump(analyzed_tsp, f)
# Out:
# Output()
# {
#     'by_destination_n': {
#         25: {
#             'mean_exec_t': 3.439603646596273,
#             'mean_cost_improvement': 0.6695635188677581,
#             'mean_iters': 181.33333333333334
#         },
#         16: {
#             'mean_exec_t': 3.870929718017578,
#             'mean_cost_improvement': 0.6121108495316185,
#             'mean_iters': 156.0
#         },
#         100: {
#             'mean_exec_t': 6.574088255564372,
#             'mean_cost_improvement': 0.8132547418197514,
#             'mean_iters': 97.66666666666667
#         },
#         49: {
#             'mean_exec_t': 6.206858396530151,
#             'mean_cost_improvement': 0.7353177274123127,
#             'mean_iters': 99.0
#         },
#         36: {
#             'mean_exec_t': 3.408618450164795,
#             'mean_cost_improvement': 0.730573837836581,
#             'mean_iters': 186.0
#         },
#         81: {
#             'mean_exec_t': 7.233170747756958,
#             'mean_cost_improvement': 0.8098253070439403,
#             'mean_iters': 81.0
#         }
#     },
#     'by_population_size': {
#         50: {
#             'mean_exec_t': 3.1627554893493652,
#             'mean_cost_improvement': 0.6338881715684,
#             'mean_iters': 191.0
#         },
#         100: {
#             'mean_exec_t': 6.206858396530151,
#             'mean_cost_improvement': 0.7353177274123127,
#             'mean_iters': 99.0
#         },
#         70: {
#             'mean_exec_t': 6.429808139801025,
#             'mean_cost_improvement': 0.8112957062982052,
#             'mean_iters': 91.0
#         },
#         40: {
#             'mean_exec_t': 3.2155887285868325,
#             'mean_cost_improvement': 0.6702495508402678,
#             'mean_iters': 195.33333333333334
#         },
#         80: {
#             'mean_exec_t': 4.429548144340515,
#             'mean_cost_improvement': 0.3999292546640363,
#             'mean_iters': 33.0
#         },
#         20: {
#             'mean_exec_t': 1.4777867794036865,
#             'mean_cost_improvement': 0.2762033366109922,
#             'mean_iters': 45.333333333333336
#         },
#         90: {
#             'mean_exec_t': 7.233170747756958,
#             'mean_cost_improvement': 0.8098253070439403,
#             'mean_iters': 81.0
#         }
#     },
#     'by_map': {
#         'data\\environments\\map_2021-12-30_12-36-44_vrp.json': {
#             'mean_exec_t': 3.439603646596273,
#             'mean_cost_improvement': 0.6695635188677581,
#             'mean_iters': 181.33333333333334,
#             'best_solution': [
#                 0,
#                 3,
#                 8,
#                 0,
#                 13,
#                 12,
#                 0,
#                 7,
#                 0,
#                 10,
#                 11,
#                 4,
#                 9,
#                 14,
#                 25,
#                 19,
#                 18,
#                 23,
#                 22,
#                 17,
#                 16,
#                 21,
#                 26,
#                 24,
#                 20,
#                 15,
#                 5,
#                 6
#             ],
#             'min_cost': 0.9934924275461863,
#             'min_cost_mean': 1.5648814301716094,
#             'min_cost_stddev': 0.8819002869149682
#         },
#         'data\\environments\\map_2021-12-30_12-35-59_vrp.json': {
#             'mean_exec_t': 3.870929718017578,
#             'mean_cost_improvement': 0.6121108495316185,
#             'mean_iters': 156.0,
#             'best_solution': [
#                 0,
#                 3,
#                 0,
#                 6,
#                 0,
#                 4,
#                 0,
#                 9,
#                 14,
#                 12,
#                 13,
#                 7,
#                 11,
#                 15,
#                 10,
#                 16,
#                 5,
#                 17,
#                 8
#             ],
#             'min_cost': 1.813942328830569,
#             'min_cost_mean': 1.813942328830569,
#             'min_cost_stddev': 0.0
#         },
#         'data\\environments\\map_2021-12-30_12-41-48_vrp.json': {
#             'mean_exec_t': 6.574088255564372,
#             'mean_cost_improvement': 0.8132547418197514,
#             'mean_iters': 97.66666666666667,
#             'best_solution': [
#                 0,
#                 12,
#                 13,
#                 39,
#                 0,
#                 15,
#                 7,
#                 36,
#                 0,
#                 3,
#                 14,
#                 22,
#                 46,
#                 27,
#                 28,
#                 0,
#                 33,
#                 0,
#                 35,
#                 44,
#                 17,
#                 16,
#                 0,
#                 4,
#                 26,
#                 18,
#                 8,
#                 0,
#                 43,
#                 37,
#                 47,
#                 38,
#                 30,
#                 23,
#                 0,
#                 32,
#                 42,
#                 24,
#                 34,
#                 45,
#                 55,
#                 63,
#                 62,
#                 73,
#                 84,
#                 40,
#                 0,
#                 53,
#                 54,
#                 64,
#                 25,
#                 65,
#                 0,
#                 6,
#                 68,
#                 66,
#                 29,
#                 19,
#                 0,
#                 48,
#                 0,
#                 72,
#                 0,
#                 52,
#                 59,
#                 60,
#                 56,
#                 0,
#                 9,
#                 78,
#                 79,
#                 57,
#                 0,
#                 58,
#                 69,
#                 80,
#                 70,
#                 77,
#                 75,
#                 95,
#                 94,
#                 0,
#                 82,
#                 93,
#                 90,
#                 91,
#                 100,
#                 89,
#                 88,
#                 99,
#                 98,
#                 97,
#                 20,
#                 11,
#                 96,
#                 86,
#                 83,
#                 76,
#                 85,
#                 74,
#                 67,
#                 5,
#                 31
#             ],
#             'min_cost': 4.635675994920386,
#             'min_cost_mean': 4.635675994920386,
#             'min_cost_stddev': 0.1400882616203477
#         },
#         'data\\environments\\map_2021-12-30_12-38-55_vrp.json': {
#             'mean_exec_t': 6.206858396530151,
#             'mean_cost_improvement': 0.7353177274123127,
#             'mean_iters': 99.0,
#             'best_solution': [
#                 0,
#                 3,
#                 11,
#                 0,
#                 4,
#                 0,
#                 16,
#                 24,
#                 0,
#                 23,
#                 9,
#                 0,
#                 30,
#                 31,
#                 0,
#                 5,
#                 13,
#                 32,
#                 0,
#                 26,
#                 33,
#                 40,
#                 47,
#                 0,
#                 19,
#                 18,
#                 20,
#                 44,
#                 38,
#                 37,
#                 10,
#                 0,
#                 22,
#                 35,
#                 36,
#                 0,
#                 6,
#                 14,
#                 12,
#                 0,
#                 7,
#                 8,
#                 17,
#                 27,
#                 28,
#                 0,
#                 45,
#                 46,
#                 0,
#                 25,
#                 34,
#                 0
#             ],
#             'min_cost': 3.0805842659216696,
#             'min_cost_mean': 3.0805842659216696,
#             'min_cost_stddev': 0.0
#         },
#         'data\\environments\\map_2021-12-30_12-38-11_vrp.json': {
#             'mean_exec_t': 3.408618450164795,
#             'mean_cost_improvement': 0.730573837836581,
#             'mean_iters': 186.0,
#             'best_solution': [
#                 0,
#                 8,
#                 22,
#                 9,
#                 1,
#                 4,
#                 15,
#                 2,
#                 3,
#                 10,
#                 14,
#                 0,
#                 16,
#                 17,
#                 5,
#                 6,
#                 0,
#                 11,
#                 12,
#                 18,
#                 0,
#                 25,
#                 31,
#                 37,
#                 30,
#                 20,
#                 0,
#                 26,
#                 33,
#                 35,
#                 0,
#                 21,
#                 29,
#                 23,
#                 24,
#                 19,
#                 0,
#                 27,
#                 0
#             ],
#             'min_cost': 2.8506402449535564,
#             'min_cost_mean': 2.8506402449535564,
#             'min_cost_stddev': 0.0
#         },
#         'data\\environments\\map_2021-12-30_12-40-24_vrp.json': {
#             'mean_exec_t': 7.233170747756958,
#             'mean_cost_improvement': 0.8098253070439403,
#             'mean_iters': 81.0,
#             'best_solution': [
#                 0,
#                 3,
#                 0,
#                 12,
#                 13,
#                 20,
#                 38,
#                 30,
#                 31,
#                 32,
#                 23,
#                 22,
#                 43,
#                 39,
#                 11,
#                 0,
#                 57,
#                 56,
#                 67,
#                 66,
#                 59,
#                 68,
#                 69,
#                 78,
#                 0,
#                 4,
#                 26,
#                 7,
#                 15,
#                 6,
#                 0,
#                 5,
#                 16,
#                 24,
#                 42,
#                 51,
#                 41,
#                 0,
#                 40,
#                 14,
#                 0,
#                 47,
#                 65,
#                 74,
#                 0,
#                 44,
#                 19,
#                 36,
#                 35,
#                 17,
#                 0,
#                 29,
#                 77,
#                 79,
#                 0,
#                 33,
#                 0,
#                 21,
#                 1,
#                 60,
#                 61,
#                 25,
#                 0,
#                 48,
#                 0,
#                 34,
#                 76,
#                 75,
#                 49,
#                 50,
#                 58,
#                 52,
#                 0,
#                 18,
#                 0,
#                 9,
#                 10,
#                 0,
#                 70,
#                 71,
#                 62,
#                 53,
#                 45,
#                 0
#             ],
#             'min_cost': 3.7767610933535383,
#             'min_cost_mean': 3.7767610933535383,
#             'min_cost_stddev': 0.0
#         }
#     }
# }
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18636/3183040044.py in <module>
#       2 rprint(analyzed_vrp)
#       3 save_path = Path("data/experiments/analyzed_vrp.json")
# ----> 4 with save_path.open("r") as f:
#       5     json.dump(analyzed_tsp, f)
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.9_3.9.2544.0_x64__qbz5n2kfra8p0\lib\pathlib.py in open(self, mode, buffering, encoding, errors, newline)
#    1250         the built-in open() function does.
#    1251         """
# -> 1252         return io.open(self, mode, buffering, encoding, errors, newline,
#    1253                        opener=self._opener)
#    1254
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.9_3.9.2544.0_x64__qbz5n2kfra8p0\lib\pathlib.py in _opener(self, name, flags, mode)
#    1118     def _opener(self, name, flags, mode=0o666):
#    1119         # A stub for the opener argument to built-in open()
# -> 1120         return self._accessor.open(self, flags, mode)
#    1121
#    1122     def _raw_open(self, flags, mode=0o777):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data\\experiments\\analyzed_vrp.json'
