# %% [markdown]
# # Analyze experiments' data

# %%
import json
from pathlib import Path

from rich import print as rprint

from bin.experiment_utils import analyze_data2

# %% [markdown]
# ## TSP

# %%
analyzed_tsp = analyze_data2(Path("data/experiments/runs/tsp/"))
rprint(analyzed_tsp)
save_path = Path("data/experiments/analyzed_tsp.json")
with save_path.open("w") as f:
    json.dump(analyzed_tsp, f)
# Out:
# Output()
# {
#     'destination_n': {
#         36: {
#             'exec_t': {'mean': 3.7955261516571044, 'stddev': 1.1484442114320328},
#             'cost_improvement': {
#                 'mean': 0.44373060893493543,
#                 'stddev': 0.04379128272199478
#             },
#             'iters': {'mean': 177.456, 'stddev': 72.93783300778114}
#         },
#         100: {
#             'exec_t': {'mean': 7.434257489139751, 'stddev': 2.3402284135278264},
#             'cost_improvement': {
#                 'mean': 0.4695771122157273,
#                 'stddev': 0.038848751965986444
#             },
#             'iters': {'mean': 91.9322033898305, 'stddev': 38.53308686230272}
#         },
#         64: {
#             'exec_t': {'mean': 5.585096115797338, 'stddev': 1.6125458021073324},
#             'cost_improvement': {'mean': 0.4571921456003192, 'stddev': 0.03640469966548153},
#             'iters': {'mean': 120.24647887323944, 'stddev': 47.76377846876256}
#         },
#         81: {
#             'exec_t': {'mean': 6.388622063548625, 'stddev': 1.9001037050920098},
#             'cost_improvement': {
#                 'mean': 0.46364441625683084,
#                 'stddev': 0.03433571482733139
#             },
#             'iters': {'mean': 105.3529411764706, 'stddev': 42.86074974139878}
#         },
#         25: {
#             'exec_t': {'mean': 3.0003092139959335, 'stddev': 0.9096061828223949},
#             'cost_improvement': {
#                 'mean': 0.4190531859113808,
#                 'stddev': 0.046634431947910907
#             },
#             'iters': {'mean': 220.70833333333334, 'stddev': 80.62230642760287}
#         },
#         16: {
#             'exec_t': {'mean': 2.4814579137941686, 'stddev': 0.694236548352436},
#             'cost_improvement': {'mean': 0.4071842547528374, 'stddev': 0.04997444084360271},
#             'iters': {'mean': 261.9593495934959, 'stddev': 91.14925594095597}
#         },
#         9: {
#             'exec_t': {'mean': 2.2294597977497537, 'stddev': 0.5829815858369377},
#             'cost_improvement': {
#                 'mean': 0.18234540968964089,
#                 'stddev': 0.07629781132584898
#             },
#             'iters': {'mean': 289.5409836065574, 'stddev': 101.83272197648566}
#         },
#         49: {
#             'exec_t': {'mean': 4.522320174725256, 'stddev': 1.4250480921766795},
#             'cost_improvement': {
#                 'mean': 0.44421461139502194,
#                 'stddev': 0.04437911800876594
#             },
#             'iters': {'mean': 150.52336448598132, 'stddev': 62.857182504046655}
#         }
#     },
#     'pop_size': {
#         100: {
#             'exec_t': {'mean': 6.170873043329819, 'stddev': 2.4424410599993505},
#             'cost_improvement': {
#                 'mean': 0.40776667093768293,
#                 'stddev': 0.09281340449654576
#             },
#             'iters': {'mean': 113.34782608695652, 'stddev': 46.2093741459288}
#         },
#         20: {
#             'exec_t': {'mean': 2.7408666157722474, 'stddev': 1.056887766736563},
#             'cost_improvement': {'mean': 0.4376444572577025, 'stddev': 0.0676533653434619},
#             'iters': {'mean': 251.31, 'stddev': 95.91975760493716}
#         },
#         30: {
#             'exec_t': {'mean': 3.4282403935988746, 'stddev': 1.4320895815618222},
#             'cost_improvement': {
#                 'mean': 0.41479127956216943,
#                 'stddev': 0.09309040460834492
#             },
#             'iters': {'mean': 206.35416666666666, 'stddev': 85.50358307871224}
#         },
#         60: {
#             'exec_t': {'mean': 4.6498405536015825, 'stddev': 2.1514816456833237},
#             'cost_improvement': {
#                 'mean': 0.37751259700370454,
#                 'stddev': 0.12964217923304974
#             },
#             'iters': {'mean': 157.88541666666666, 'stddev': 68.72215145698796}
#         },
#         80: {
#             'exec_t': {'mean': 5.768591813670779, 'stddev': 2.3457343454631965},
#             'cost_improvement': {'mean': 0.4111061718136298, 'stddev': 0.10226097679327475},
#             'iters': {'mean': 123.99029126213593, 'stddev': 55.169168561056416}
#         },
#         10: {
#             'exec_t': {'mean': 2.0571010579233584, 'stddev': 0.7521421007012817},
#             'cost_improvement': {
#                 'mean': 0.43996133094394313,
#                 'stddev': 0.07113655698269782
#             },
#             'iters': {'mean': 331.9673913043478, 'stddev': 124.16777475506846}
#         },
#         90: {
#             'exec_t': {'mean': 5.615666382383592, 'stddev': 2.3477577445083657},
#             'cost_improvement': {'mean': 0.38813001903093997, 'stddev': 0.123029637428252},
#             'iters': {'mean': 126.85148514851485, 'stddev': 53.735907201537756}
#         },
#         40: {
#             'exec_t': {'mean': 3.9088056693642828, 'stddev': 1.5448935807315887},
#             'cost_improvement': {'mean': 0.4199383377916364, 'stddev': 0.0838664223047691},
#             'iters': {'mean': 178.82203389830508, 'stddev': 72.77945039121073}
#         },
#         70: {
#             'exec_t': {'mean': 4.980106035868327, 'stddev': 2.0899963333381857},
#             'cost_improvement': {
#                 'mean': 0.40057285418788824,
#                 'stddev': 0.10626221061198796
#             },
#             'iters': {'mean': 141.27956989247312, 'stddev': 57.179611293179356}
#         },
#         50: {
#             'exec_t': {'mean': 4.640979718724522, 'stddev': 2.0116232863080015},
#             'cost_improvement': {'mean': 0.4129189000766335, 'stddev': 0.09897897579974572},
#             'iters': {'mean': 157.6605504587156, 'stddev': 72.47773862359729}
#         }
#     },
#     'crossover': {
#         'crossover_ndarray': {
#             'exec_t': {'mean': 3.8966010349606157, 'stddev': 2.033740203693016},
#             'cost_improvement': {
#                 'mean': 0.39909771025617236,
#                 'stddev': 0.09934583299528503
#             },
#             'iters': {'mean': 201.08256880733944, 'stddev': 113.54713416163408}
#         },
#         'crossover_k_loci_poisson_ndarray': {
#             'exec_t': {'mean': 4.3537530019548205, 'stddev': 2.2848813184624728},
#             'cost_improvement': {
#                 'mean': 0.41215637079604067,
#                 'stddev': 0.11186886996224962
#             },
#             'iters': {'mean': 180.13777777777779, 'stddev': 96.12911538861067}
#         },
#         'crossover_k_loci_with_inversion_ndarray': {
#             'exec_t': {'mean': 4.734545802543177, 'stddev': 2.4501224328485085},
#             'cost_improvement': {
#                 'mean': 0.41177904853702935,
#                 'stddev': 0.09365488090918103
#             },
#             'iters': {'mean': 164.95027624309392, 'stddev': 88.40426562377418}
#         },
#         'crossover_k_loci_ndarray': {
#             'exec_t': {'mean': 4.346810098904283, 'stddev': 2.2786881690555703},
#             'cost_improvement': {'mean': 0.4184256468591544, 'stddev': 0.09871345789113305},
#             'iters': {'mean': 180.044776119403, 'stddev': 99.15499475606173}
#         },
#         'crossover_k_loci_poisson_with_inversion_ndarray': {
#             'exec_t': {'mean': 4.791108341217041, 'stddev': 2.2160376718668156},
#             'cost_improvement': {
#                 'mean': 0.41601013718014423,
#                 'stddev': 0.09062435502182903
#             },
#             'iters': {'mean': 158.0742857142857, 'stddev': 84.19701971019413}
#         }
#     },
#     'map': {
#         'data\\environments\\map_2021-12-29_20-35-35_tsp.json': {
#             'exec_t': {'mean': 3.7955261516571044, 'stddev': 1.1484442114320328},
#             'cost_improvement': {
#                 'mean': 0.44373060893493543,
#                 'stddev': 0.04379128272199478
#             },
#             'iters': {'mean': 177.456, 'stddev': 72.93783300778114}
#         },
#         'data\\environments\\map_2021-12-29_20-41-35_tsp.json': {
#             'exec_t': {'mean': 7.434257489139751, 'stddev': 2.3402284135278264},
#             'cost_improvement': {
#                 'mean': 0.4695771122157273,
#                 'stddev': 0.038848751965986444
#             },
#             'iters': {'mean': 91.9322033898305, 'stddev': 38.53308686230272}
#         },
#         'data\\environments\\map_2021-12-29_20-40-55_tsp.json': {
#             'exec_t': {'mean': 5.585096115797338, 'stddev': 1.6125458021073324},
#             'cost_improvement': {'mean': 0.4571921456003192, 'stddev': 0.03640469966548153},
#             'iters': {'mean': 120.24647887323944, 'stddev': 47.76377846876256}
#         },
#         'data\\environments\\map_2021-12-29_20-41-17_tsp.json': {
#             'exec_t': {'mean': 6.388622063548625, 'stddev': 1.9001037050920098},
#             'cost_improvement': {
#                 'mean': 0.46364441625683084,
#                 'stddev': 0.03433571482733139
#             },
#             'iters': {'mean': 105.3529411764706, 'stddev': 42.86074974139878}
#         },
#         'data\\environments\\map_2021-12-29_20-34-33_tsp.json': {
#             'exec_t': {'mean': 3.0003092139959335, 'stddev': 0.9096061828223949},
#             'cost_improvement': {
#                 'mean': 0.4190531859113808,
#                 'stddev': 0.046634431947910907
#             },
#             'iters': {'mean': 220.70833333333334, 'stddev': 80.62230642760287}
#         },
#         'data\\environments\\map_2021-12-29_20-33-28_tsp.json': {
#             'exec_t': {'mean': 2.4814579137941686, 'stddev': 0.694236548352436},
#             'cost_improvement': {'mean': 0.4071842547528374, 'stddev': 0.04997444084360271},
#             'iters': {'mean': 261.9593495934959, 'stddev': 91.14925594095597}
#         },
#         'data\\environments\\map_2021-12-29_20-32-46_tsp.json': {
#             'exec_t': {'mean': 2.2294597977497537, 'stddev': 0.5829815858369377},
#             'cost_improvement': {
#                 'mean': 0.18234540968964089,
#                 'stddev': 0.07629781132584898
#             },
#             'iters': {'mean': 289.5409836065574, 'stddev': 101.83272197648566}
#         },
#         'data\\environments\\map_2021-12-29_20-40-23_tsp.json': {
#             'exec_t': {'mean': 4.522320174725256, 'stddev': 1.4250480921766795},
#             'cost_improvement': {
#                 'mean': 0.44421461139502194,
#                 'stddev': 0.04437911800876594
#             },
#             'iters': {'mean': 150.52336448598132, 'stddev': 62.857182504046655}
#         }
#     }
# }

# %% [markdown]
# ## VRP

# %%
analyzed_vrp = analyze_data2(Path("data/experiments/runs/vrp/"))
rprint(analyzed_vrp)
save_path = Path("data/experiments/analyzed_vrp.json")
with save_path.open("w") as f:
    json.dump(analyzed_vrp, f)
# Out:
# Output()
# {
#     'destination_n': {
#         9: {
#             'exec_t': {'mean': 2.8321861028671265, 'stddev': 0.8622690996838307},
#             'cost_improvement': {
#                 'mean': 0.39363026843008003,
#                 'stddev': 0.12715469705032895
#             },
#             'iters': {'mean': 237.97169811320754, 'stddev': 95.33294614112212}
#         },
#         100: {
#             'exec_t': {'mean': 7.893517068580345, 'stddev': 2.2889910201437544},
#             'cost_improvement': {'mean': 0.7864908711771027, 'stddev': 0.04057675108133466},
#             'iters': {'mean': 85.67407407407407, 'stddev': 36.140445286643335}
#         },
#         81: {
#             'exec_t': {'mean': 6.839372419885227, 'stddev': 1.8870639949530283},
#             'cost_improvement': {'mean': 0.7871366236668687, 'stddev': 0.02772951795798773},
#             'iters': {'mean': 96.14285714285714, 'stddev': 33.36607143933375}
#         },
#         36: {
#             'exec_t': {'mean': 4.3998577655890045, 'stddev': 1.267937701785615},
#             'cost_improvement': {'mean': 0.7066390799108218, 'stddev': 0.04109590026918703},
#             'iters': {'mean': 152.4957264957265, 'stddev': 60.14474264461209}
#         },
#         25: {
#             'exec_t': {'mean': 3.6980802395960666, 'stddev': 1.0721713300608335},
#             'cost_improvement': {'mean': 0.6748036542675873, 'stddev': 0.06906454681920973},
#             'iters': {'mean': 180.0909090909091, 'stddev': 66.45054383470685}
#         },
#         64: {
#             'exec_t': {'mean': 5.666021306991577, 'stddev': 1.7785344866732833},
#             'cost_improvement': {
#                 'mean': 0.7615231620041013,
#                 'stddev': 0.024500642392328742
#             },
#             'iters': {'mean': 119.888, 'stddev': 47.21061526339587}
#         },
#         49: {
#             'exec_t': {'mean': 4.880340472975774, 'stddev': 1.3769015163620588},
#             'cost_improvement': {
#                 'mean': 0.7431699439810374,
#                 'stddev': 0.023791902922073154
#             },
#             'iters': {'mean': 136.59701492537314, 'stddev': 52.76905555441597}
#         },
#         16: {
#             'exec_t': {'mean': 3.168718634173274, 'stddev': 0.9134182547476579},
#             'cost_improvement': {'mean': 0.6102408551697036, 'stddev': 0.10564645950315518},
#             'iters': {'mean': 210.8828125, 'stddev': 80.74277433786624}
#         }
#     },
#     'pop_size': {
#         60: {
#             'exec_t': {'mean': 5.405819996268348, 'stddev': 1.8278639673264907},
#             'cost_improvement': {'mean': 0.6756326657026569, 'stddev': 0.14048645073871285},
#             'iters': {'mean': 124.27433628318585, 'stddev': 41.302293214526976}
#         },
#         100: {
#             'exec_t': {'mean': 6.4954344573773835, 'stddev': 2.153752218017602},
#             'cost_improvement': {'mean': 0.6681583082559974, 'stddev': 0.1546230818529303},
#             'iters': {'mean': 102.28421052631579, 'stddev': 32.93050812030677}
#         },
#         10: {
#             'exec_t': {'mean': 2.157414101539774, 'stddev': 0.7004891869203876},
#             'cost_improvement': {'mean': 0.7156275710445521, 'stddev': 0.11261016138285795},
#             'iters': {'mean': 305.8829787234043, 'stddev': 93.58336590349536}
#         },
#         90: {
#             'exec_t': {'mean': 6.566592956326671, 'stddev': 2.166454732675427},
#             'cost_improvement': {'mean': 0.676670331287024, 'stddev': 0.1360330261142377},
#             'iters': {'mean': 101.47422680412372, 'stddev': 32.3055377036666}
#         },
#         30: {
#             'exec_t': {'mean': 3.74941356347339, 'stddev': 1.0955033324825427},
#             'cost_improvement': {'mean': 0.6972779216616161, 'stddev': 0.11706091430458275},
#             'iters': {'mean': 173.27722772277227, 'stddev': 48.917710251376484}
#         },
#         40: {
#             'exec_t': {'mean': 4.373024971396835, 'stddev': 1.5275066720200137},
#             'cost_improvement': {'mean': 0.703407485075741, 'stddev': 0.13423974411131967},
#             'iters': {'mean': 153.2314814814815, 'stddev': 49.27276863162676}
#         },
#         50: {
#             'exec_t': {'mean': 4.965890995005972, 'stddev': 1.6050001157859273},
#             'cost_improvement': {'mean': 0.6946330303747277, 'stddev': 0.11594341351254737},
#             'iters': {'mean': 133.57731958762886, 'stddev': 42.33542523986915}
#         },
#         80: {
#             'exec_t': {'mean': 6.193769767366606, 'stddev': 2.318956339173674},
#             'cost_improvement': {'mean': 0.668785083877145, 'stddev': 0.16509378628295399},
#             'iters': {'mean': 110.69827586206897, 'stddev': 38.87084966299603}
#         },
#         20: {
#             'exec_t': {'mean': 3.0362582260303284, 'stddev': 0.9750289171251348},
#             'cost_improvement': {'mean': 0.6887069329929677, 'stddev': 0.11381645651438088},
#             'iters': {'mean': 218.14606741573033, 'stddev': 68.85071970340776}
#         },
#         70: {
#             'exec_t': {'mean': 6.157953368292914, 'stddev': 2.0392455750392102},
#             'cost_improvement': {'mean': 0.6971784057609722, 'stddev': 0.12797860102232445},
#             'iters': {'mean': 109.08888888888889, 'stddev': 36.965712763314535}
#         }
#     },
#     'crossover': {
#         'crossover_k_loci_ndarray': {
#             'exec_t': {'mean': 4.919188971746536, 'stddev': 2.1827270146225106},
#             'cost_improvement': {'mean': 0.6779497795376366, 'stddev': 0.14392413515936114},
#             'iters': {'mean': 149.25238095238095, 'stddev': 74.2632593741248}
#         },
#         'crossover_k_loci_with_inversion_ndarray': {
#             'exec_t': {'mean': 5.096838314934533, 'stddev': 2.27990373453344},
#             'cost_improvement': {'mean': 0.6803198466623439, 'stddev': 0.14916189974957428},
#             'iters': {'mean': 145.2970297029703, 'stddev': 71.86458306837348}
#         },
#         'crossover_k_loci_poisson_ndarray': {
#             'exec_t': {'mean': 4.993413422788892, 'stddev': 2.3726742538576135},
#             'cost_improvement': {'mean': 0.6964356988594512, 'stddev': 0.11958781707402479},
#             'iters': {'mean': 153.5612244897959, 'stddev': 84.48608640741773}
#         },
#         'crossover_k_loci_poisson_with_inversion_ndarray': {
#             'exec_t': {'mean': 5.1268602967262265, 'stddev': 2.3975339780451614},
#             'cost_improvement': {'mean': 0.6880782153124606, 'stddev': 0.13812116932048718},
#             'iters': {'mean': 147.135, 'stddev': 74.59819857848967}
#         },
#         'crossover_ndarray': {
#             'exec_t': {'mean': 4.5656105888386564, 'stddev': 1.953775842688011},
#             'cost_improvement': {'mean': 0.6990050378180718, 'stddev': 0.11454154959286082},
#             'iters': {'mean': 162.59895833333334, 'stddev': 88.35009251311958}
#         }
#     },
#     'map': {
#         'data\\environments\\map_2021-12-30_12-35-22_vrp.json': {
#             'exec_t': {'mean': 2.8321861028671265, 'stddev': 0.8622690996838307},
#             'cost_improvement': {
#                 'mean': 0.39363026843008003,
#                 'stddev': 0.12715469705032895
#             },
#             'iters': {'mean': 237.97169811320754, 'stddev': 95.33294614112212}
#         },
#         'data\\environments\\map_2021-12-30_12-41-48_vrp.json': {
#             'exec_t': {'mean': 7.893517068580345, 'stddev': 2.2889910201437544},
#             'cost_improvement': {'mean': 0.7864908711771027, 'stddev': 0.04057675108133466},
#             'iters': {'mean': 85.67407407407407, 'stddev': 36.140445286643335}
#         },
#         'data\\environments\\map_2021-12-30_12-40-24_vrp.json': {
#             'exec_t': {'mean': 6.839372419885227, 'stddev': 1.8870639949530283},
#             'cost_improvement': {'mean': 0.7871366236668687, 'stddev': 0.02772951795798773},
#             'iters': {'mean': 96.14285714285714, 'stddev': 33.36607143933375}
#         },
#         'data\\environments\\map_2021-12-30_12-38-11_vrp.json': {
#             'exec_t': {'mean': 4.3998577655890045, 'stddev': 1.267937701785615},
#             'cost_improvement': {'mean': 0.7066390799108218, 'stddev': 0.04109590026918703},
#             'iters': {'mean': 152.4957264957265, 'stddev': 60.14474264461209}
#         },
#         'data\\environments\\map_2021-12-30_12-36-44_vrp.json': {
#             'exec_t': {'mean': 3.6980802395960666, 'stddev': 1.0721713300608335},
#             'cost_improvement': {'mean': 0.6748036542675873, 'stddev': 0.06906454681920973},
#             'iters': {'mean': 180.0909090909091, 'stddev': 66.45054383470685}
#         },
#         'data\\environments\\map_2021-12-30_12-39-34_vrp.json': {
#             'exec_t': {'mean': 5.666021306991577, 'stddev': 1.7785344866732833},
#             'cost_improvement': {
#                 'mean': 0.7615231620041013,
#                 'stddev': 0.024500642392328742
#             },
#             'iters': {'mean': 119.888, 'stddev': 47.21061526339587}
#         },
#         'data\\environments\\map_2021-12-30_12-38-55_vrp.json': {
#             'exec_t': {'mean': 4.880340472975774, 'stddev': 1.3769015163620588},
#             'cost_improvement': {
#                 'mean': 0.7431699439810374,
#                 'stddev': 0.023791902922073154
#             },
#             'iters': {'mean': 136.59701492537314, 'stddev': 52.76905555441597}
#         },
#         'data\\environments\\map_2021-12-30_12-35-59_vrp.json': {
#             'exec_t': {'mean': 3.168718634173274, 'stddev': 0.9134182547476579},
#             'cost_improvement': {'mean': 0.6102408551697036, 'stddev': 0.10564645950315518},
#             'iters': {'mean': 210.8828125, 'stddev': 80.74277433786624}
#         }
#     }
# }

# %% [markdown]
# ## VRPP

# %%
analyzed_vrpp = analyze_data2(Path("data/experiments/runs/vrpp/"))
rprint(analyzed_vrpp)
save_path = Path("data/experiments/analyzed_vrpp.json")
with save_path.open("w") as f:
    json.dump(analyzed_vrpp, f)
# Out:
# Output()
# {
#     'destination_n': {
#         64: {
#             'exec_t': {'mean': 13.287033960223198, 'stddev': 8.027487458991748},
#             'cost_improvement': {'mean': 33.85036708598414, 'stddev': 19.330073869273235},
#             'iters': {'mean': 91.05555555555556, 'stddev': 42.72399266617704}
#         },
#         16: {
#             'exec_t': {'mean': 9.622281599852998, 'stddev': 6.100178750597267},
#             'cost_improvement': {'mean': 42.92043359579379, 'stddev': 27.58485117695502},
#             'iters': {'mean': 137.88983050847457, 'stddev': 77.46736659491218}
#         },
#         100: {
#             'exec_t': {'mean': 13.812412670942454, 'stddev': 8.249253593797373},
#             'cost_improvement': {'mean': 24.070804605514, 'stddev': 13.849125076265151},
#             'iters': {'mean': 79.02307692307693, 'stddev': 35.612136548217954}
#         },
#         49: {
#             'exec_t': {'mean': 13.900157822144998, 'stddev': 8.84662535223746},
#             'cost_improvement': {'mean': 38.51878736664016, 'stddev': 20.374933087923214},
#             'iters': {'mean': 98.67567567567568, 'stddev': 50.560022417788694}
#         },
#         25: {
#             'exec_t': {'mean': 10.948321218843814, 'stddev': 6.058440364608426},
#             'cost_improvement': {'mean': 37.94344188318499, 'stddev': 20.371133223911606},
#             'iters': {'mean': 113, 'stddev': 44.97933066327119}
#         },
#         36: {
#             'exec_t': {'mean': 12.310384317066358, 'stddev': 7.884384865775303},
#             'cost_improvement': {'mean': 34.65276360490545, 'stddev': 18.254880940081094},
#             'iters': {'mean': 111.11304347826086, 'stddev': 60.19132729062274}
#         },
#         81: {
#             'exec_t': {'mean': 13.813644441274496, 'stddev': 9.332277203028346},
#             'cost_improvement': {'mean': 27.903328440288107, 'stddev': 16.517094938301582},
#             'iters': {'mean': 86.47115384615384, 'stddev': 43.94722270089127}
#         },
#         9: {
#             'exec_t': {'mean': 9.315209580543346, 'stddev': 4.890043738707218},
#             'cost_improvement': {'mean': 29.63927887557154, 'stddev': 14.867075985926723},
#             'iters': {'mean': 126.21804511278195, 'stddev': 64.98721766459792}
#         }
#     },
#     'pop_size': {
#         20: {
#             'exec_t': {'mean': 9.480127469147787, 'stddev': 4.58580807899275},
#             'cost_improvement': {'mean': 36.82296193884419, 'stddev': 18.23769785848731},
#             'iters': {'mean': 132.990099009901, 'stddev': 60.96416899286087}
#         },
#         70: {
#             'exec_t': {'mean': 13.97847538045112, 'stddev': 9.33384217276521},
#             'cost_improvement': {'mean': 32.15761502769415, 'stddev': 19.61424865067265},
#             'iters': {'mean': 89.30851063829788, 'stddev': 41.0986294922963}
#         },
#         100: {
#             'exec_t': {'mean': 14.816012552151314, 'stddev': 8.60804326035352},
#             'cost_improvement': {'mean': 31.99504160580576, 'stddev': 20.676392703905552},
#             'iters': {'mean': 75.65384615384616, 'stddev': 26.661039983928706}
#         },
#         60: {
#             'exec_t': {'mean': 13.989884254094717, 'stddev': 8.491835574133784},
#             'cost_improvement': {'mean': 34.74759404931514, 'stddev': 19.83827930718295},
#             'iters': {'mean': 88.78378378378379, 'stddev': 38.39564497212611}
#         },
#         40: {
#             'exec_t': {'mean': 11.6724443596143, 'stddev': 6.274262994339643},
#             'cost_improvement': {'mean': 35.58383746542968, 'stddev': 19.712917047934013},
#             'iters': {'mean': 102.72115384615384, 'stddev': 42.5394064552896}
#         },
#         90: {
#             'exec_t': {'mean': 14.409383825633837, 'stddev': 9.169302044163738},
#             'cost_improvement': {'mean': 30.413619584226343, 'stddev': 20.17380900395452},
#             'iters': {'mean': 78.6413043478261, 'stddev': 30.530324151333136}
#         },
#         10: {
#             'exec_t': {'mean': 7.375235054471077, 'stddev': 3.638764082829084},
#             'cost_improvement': {'mean': 34.62574368418493, 'stddev': 16.938429302575212},
#             'iters': {'mean': 168.94495412844037, 'stddev': 85.56260809991119}
#         },
#         80: {
#             'exec_t': {'mean': 13.675504498429351, 'stddev': 8.19709225057381},
#             'cost_improvement': {'mean': 30.31701530655812, 'stddev': 20.547680056104674},
#             'iters': {'mean': 83.02197802197803, 'stddev': 34.69965674565353}
#         },
#         30: {
#             'exec_t': {'mean': 9.399858304045416, 'stddev': 5.364050159241289},
#             'cost_improvement': {'mean': 33.70547328014717, 'stddev': 22.13826844106128},
#             'iters': {'mean': 124.93181818181819, 'stddev': 52.87912815428567}
#         },
#         50: {
#             'exec_t': {'mean': 13.159295320510864, 'stddev': 7.983592406382592},
#             'cost_improvement': {'mean': 35.581778336512556, 'stddev': 22.16867890362435},
#             'iters': {'mean': 99.90566037735849, 'stddev': 49.1881767253041}
#         }
#     },
#     'crossover': {
#         'crossover_ndarray': {
#             'exec_t': {'mean': 15.045561281918305, 'stddev': 8.592825696242933},
#             'cost_improvement': {'mean': 41.01377456476403, 'stddev': 19.957062865281483},
#             'iters': {'mean': 91.38916256157636, 'stddev': 53.26954882917202}
#         },
#         'crossover_k_loci_ndarray': {
#             'exec_t': {'mean': 11.276478773838765, 'stddev': 7.328247616853392},
#             'cost_improvement': {'mean': 30.92068352478052, 'stddev': 19.54854555355937},
#             'iters': {'mean': 107.62162162162163, 'stddev': 54.792370616636354}
#         },
#         'crossover_k_loci_poisson_ndarray': {
#             'exec_t': {'mean': 10.724568657200745, 'stddev': 7.134583051487542},
#             'cost_improvement': {'mean': 31.626314211225917, 'stddev': 20.2834749693294},
#             'iters': {'mean': 116.8989898989899, 'stddev': 62.61622613687496}
#         },
#         'crossover_k_loci_with_inversion_ndarray': {
#             'exec_t': {'mean': 11.548428388989025, 'stddev': 7.104987145006284},
#             'cost_improvement': {'mean': 32.49708403228611, 'stddev': 19.986386624331963},
#             'iters': {'mean': 109.16591928251121, 'stddev': 62.18661471320779}
#         },
#         'crossover_k_loci_poisson_with_inversion_ndarray': {
#             'exec_t': {'mean': 12.23084958061498, 'stddev': 7.914938167346954},
#             'cost_improvement': {'mean': 32.151813079057604, 'stddev': 18.74225742798085},
#             'iters': {'mean': 99.84293193717278, 'stddev': 46.57485700506993}
#         }
#     },
#     'map': {
#         'data\\environments\\map_2021-12-30_12-39-34_vrp.json': {
#             'exec_t': {'mean': 13.287033960223198, 'stddev': 8.027487458991748},
#             'cost_improvement': {'mean': 33.85036708598414, 'stddev': 19.330073869273235},
#             'iters': {'mean': 91.05555555555556, 'stddev': 42.72399266617704}
#         },
#         'data\\environments\\map_2021-12-30_12-35-59_vrp.json': {
#             'exec_t': {'mean': 9.622281599852998, 'stddev': 6.100178750597267},
#             'cost_improvement': {'mean': 42.92043359579379, 'stddev': 27.58485117695502},
#             'iters': {'mean': 137.88983050847457, 'stddev': 77.46736659491218}
#         },
#         'data\\environments\\map_2021-12-30_12-41-48_vrp.json': {
#             'exec_t': {'mean': 13.812412670942454, 'stddev': 8.249253593797373},
#             'cost_improvement': {'mean': 24.070804605514, 'stddev': 13.849125076265151},
#             'iters': {'mean': 79.02307692307693, 'stddev': 35.612136548217954}
#         },
#         'data\\environments\\map_2021-12-30_12-38-55_vrp.json': {
#             'exec_t': {'mean': 13.900157822144998, 'stddev': 8.84662535223746},
#             'cost_improvement': {'mean': 38.51878736664016, 'stddev': 20.374933087923214},
#             'iters': {'mean': 98.67567567567568, 'stddev': 50.560022417788694}
#         },
#         'data\\environments\\map_2021-12-30_12-36-44_vrp.json': {
#             'exec_t': {'mean': 10.948321218843814, 'stddev': 6.058440364608426},
#             'cost_improvement': {'mean': 37.94344188318499, 'stddev': 20.371133223911606},
#             'iters': {'mean': 113, 'stddev': 44.97933066327119}
#         },
#         'data\\environments\\map_2021-12-30_12-38-11_vrp.json': {
#             'exec_t': {'mean': 12.310384317066358, 'stddev': 7.884384865775303},
#             'cost_improvement': {'mean': 34.65276360490545, 'stddev': 18.254880940081094},
#             'iters': {'mean': 111.11304347826086, 'stddev': 60.19132729062274}
#         },
#         'data\\environments\\map_2021-12-30_12-40-24_vrp.json': {
#             'exec_t': {'mean': 13.813644441274496, 'stddev': 9.332277203028346},
#             'cost_improvement': {'mean': 27.903328440288107, 'stddev': 16.517094938301582},
#             'iters': {'mean': 86.47115384615384, 'stddev': 43.94722270089127}
#         },
#         'data\\environments\\map_2021-12-30_12-35-22_vrp.json': {
#             'exec_t': {'mean': 9.315209580543346, 'stddev': 4.890043738707218},
#             'cost_improvement': {'mean': 29.63927887557154, 'stddev': 14.867075985926723},
#             'iters': {'mean': 126.21804511278195, 'stddev': 64.98721766459792}
#         }
#     }
# }

# %% [markdown]
# ## IRP

# %%
analyzed_irp = analyze_data2(Path("data/experiments/runs/irp/"))
rprint(analyzed_irp)
save_path = Path("data/experiments/analyzed_irp.json")
with save_path.open("w") as f:
    json.dump(analyzed_irp, f)
# Out:
# Output()
# {
#     'destination_n': {
#         9: {
#             'exec_t': {'mean': 4.022947637364268, 'stddev': 1.2236550250003717},
#             'cost_improvement': {'mean': 0.3105235988653875, 'stddev': 0.13294491152222254},
#             'iters': {'mean': 177.421875, 'stddev': 66.55512301548468}
#         },
#         81: {
#             'exec_t': {'mean': 5.998059889501777, 'stddev': 2.0614143514794523},
#             'cost_improvement': {
#                 'mean': 0.1918665322809489,
#                 'stddev': 0.025546266796793702
#             },
#             'iters': {'mean': 120.53719008264463, 'stddev': 54.41293371407115}
#         },
#         16: {
#             'exec_t': {'mean': 4.057674480602145, 'stddev': 1.3005106330658733},
#             'cost_improvement': {
#                 'mean': 0.18940027881696342,
#                 'stddev': 0.06374314092841736
#             },
#             'iters': {'mean': 172.796875, 'stddev': 65.86473365742687}
#         },
#         36: {
#             'exec_t': {'mean': 4.823905975478036, 'stddev': 1.9242477451746616},
#             'cost_improvement': {'mean': 0.156394237577337, 'stddev': 0.034431405880660335},
#             'iters': {'mean': 156.00714285714287, 'stddev': 65.83153739294727}
#         },
#         100: {
#             'exec_t': {'mean': 6.79059486572559, 'stddev': 2.2539760292248827},
#             'cost_improvement': {
#                 'mean': 0.21750530999128562,
#                 'stddev': 0.025065615060612695
#             },
#             'iters': {'mean': 103.58461538461539, 'stddev': 46.3770834573064}
#         },
#         64: {
#             'exec_t': {'mean': 5.940063194606616, 'stddev': 2.2526656841050623},
#             'cost_improvement': {
#                 'mean': 0.17043781274966693,
#                 'stddev': 0.023904253541467847
#             },
#             'iters': {'mean': 121.00869565217391, 'stddev': 46.330145476381794}
#         },
#         49: {
#             'exec_t': {'mean': 4.911083377176715, 'stddev': 1.590782913887969},
#             'cost_improvement': {
#                 'mean': 0.15226371995729882,
#                 'stddev': 0.024399707487170564
#             },
#             'iters': {'mean': 144.04032258064515, 'stddev': 59.22472006317769}
#         },
#         25: {
#             'exec_t': {'mean': 4.430200081122549, 'stddev': 1.3209688906146295},
#             'cost_improvement': {
#                 'mean': 0.15279860087004654,
#                 'stddev': 0.04404922833304648
#             },
#             'iters': {'mean': 155.58771929824562, 'stddev': 60.24372495556926}
#         }
#     },
#     'pop_size': {
#         10: {
#             'exec_t': {'mean': 2.991845211157432, 'stddev': 2.8199488008955487},
#             'cost_improvement': {'mean': 0.24380937827680052, 'stddev': 0.1269165166149336},
#             'iters': {'mean': 275.84615384615387, 'stddev': 55.530761042477025}
#         },
#         80: {
#             'exec_t': {'mean': 6.448291274004204, 'stddev': 1.5462125230771646},
#             'cost_improvement': {
#                 'mean': 0.17706866134520646,
#                 'stddev': 0.05405931245568634
#             },
#             'iters': {'mean': 101.73643410852713, 'stddev': 22.661406957867325}
#         },
#         20: {
#             'exec_t': {'mean': 3.1437810471183374, 'stddev': 0.6536220098605188},
#             'cost_improvement': {
#                 'mean': 0.21427522092424678,
#                 'stddev': 0.09119464551966942
#             },
#             'iters': {'mean': 206.97894736842105, 'stddev': 38.058180250592144}
#         },
#         70: {
#             'exec_t': {'mean': 5.893524697332671, 'stddev': 1.3867920351593994},
#             'cost_improvement': {
#                 'mean': 0.18218760911067255,
#                 'stddev': 0.06335298522251108
#             },
#             'iters': {'mean': 110.64646464646465, 'stddev': 23.034274874768478}
#         },
#         40: {
#             'exec_t': {'mean': 4.640643511878119, 'stddev': 1.0236383139011522},
#             'cost_improvement': {
#                 'mean': 0.19382584947894604,
#                 'stddev': 0.07394528524521032
#             },
#             'iters': {'mean': 139.55555555555554, 'stddev': 30.019885211553632}
#         },
#         50: {
#             'exec_t': {'mean': 5.107060774989511, 'stddev': 1.265791221759517},
#             'cost_improvement': {'mean': 0.18851465531756423, 'stddev': 0.0554892127024378},
#             'iters': {'mean': 129.183908045977, 'stddev': 28.87323083702602}
#         },
#         90: {
#             'exec_t': {'mean': 6.328121425850051, 'stddev': 1.4861684351375544},
#             'cost_improvement': {
#                 'mean': 0.17880260546928464,
#                 'stddev': 0.06170571715550122
#             },
#             'iters': {'mean': 102.19642857142857, 'stddev': 20.569740430161517}
#         },
#         30: {
#             'exec_t': {'mean': 3.920750413622175, 'stddev': 0.8633705225518624},
#             'cost_improvement': {'mean': 0.2029531920523078, 'stddev': 0.06726663120858992},
#             'iters': {'mean': 165.71428571428572, 'stddev': 33.86986245052646}
#         },
#         60: {
#             'exec_t': {'mean': 5.2392396330833435, 'stddev': 1.2142428946098018},
#             'cost_improvement': {
#                 'mean': 0.18651018802912087,
#                 'stddev': 0.058821667454319757
#             },
#             'iters': {'mean': 123.83333333333333, 'stddev': 24.678088097105782}
#         },
#         100: {
#             'exec_t': {'mean': 7.028811743384914, 'stddev': 1.5796005116418768},
#             'cost_improvement': {'mean': 0.1667199407033853, 'stddev': 0.05894010569210233},
#             'iters': {'mean': 92.18947368421053, 'stddev': 20.242305991356428}
#         }
#     },
#     'crossover': {
#         'crossover_k_loci_poisson_with_inversion_ndarray': {
#             'exec_t': {'mean': 4.8995968479177225, 'stddev': 1.8641840796407982},
#             'cost_improvement': {
#                 'mean': 0.19781765054153658,
#                 'stddev': 0.09070497869031272
#             },
#             'iters': {'mean': 150.44565217391303, 'stddev': 68.22629721204525}
#         },
#         'crossover_k_loci_poisson_ndarray': {
#             'exec_t': {'mean': 5.31599377989769, 'stddev': 1.9625798837919213},
#             'cost_improvement': {
#                 'mean': 0.19010513992102993,
#                 'stddev': 0.07309468886371404
#             },
#             'iters': {'mean': 136.31, 'stddev': 59.34757427952992}
#         },
#         'crossover_ndarray': {
#             'exec_t': {'mean': 5.342362869977951, 'stddev': 2.3766529826288214},
#             'cost_improvement': {
#                 'mean': 0.19539560491198268,
#                 'stddev': 0.08159094276663532
#             },
#             'iters': {'mean': 142.375, 'stddev': 59.547830317127314}
#         },
#         'crossover_k_loci_with_inversion_ndarray': {
#             'exec_t': {'mean': 5.093135756941942, 'stddev': 1.9541622109137884},
#             'cost_improvement': {
#                 'mean': 0.18683708555813683,
#                 'stddev': 0.056169687320086474
#             },
#             'iters': {'mean': 143.09615384615384, 'stddev': 63.63900593914928}
#         },
#         'crossover_k_loci_ndarray': {
#             'exec_t': {'mean': 4.917134975011532, 'stddev': 1.8696103811164226},
#             'cost_improvement': {'mean': 0.196713317724973, 'stddev': 0.08111046807451945},
#             'iters': {'mean': 149.28365384615384, 'stddev': 67.26392837186113}
#         }
#     },
#     'map': {
#         'data\\environments\\map_2021-12-30_12-35-22_vrp.json': {
#             'exec_t': {'mean': 4.022947637364268, 'stddev': 1.2236550250003717},
#             'cost_improvement': {'mean': 0.3105235988653875, 'stddev': 0.13294491152222254},
#             'iters': {'mean': 177.421875, 'stddev': 66.55512301548468}
#         },
#         'data\\environments\\map_2021-12-30_12-40-24_vrp.json': {
#             'exec_t': {'mean': 5.998059889501777, 'stddev': 2.0614143514794523},
#             'cost_improvement': {
#                 'mean': 0.1918665322809489,
#                 'stddev': 0.025546266796793702
#             },
#             'iters': {'mean': 120.53719008264463, 'stddev': 54.41293371407115}
#         },
#         'data\\environments\\map_2021-12-30_12-35-59_vrp.json': {
#             'exec_t': {'mean': 4.057674480602145, 'stddev': 1.3005106330658733},
#             'cost_improvement': {
#                 'mean': 0.18940027881696342,
#                 'stddev': 0.06374314092841736
#             },
#             'iters': {'mean': 172.796875, 'stddev': 65.86473365742687}
#         },
#         'data\\environments\\map_2021-12-30_12-38-11_vrp.json': {
#             'exec_t': {'mean': 4.823905975478036, 'stddev': 1.9242477451746616},
#             'cost_improvement': {'mean': 0.156394237577337, 'stddev': 0.034431405880660335},
#             'iters': {'mean': 156.00714285714287, 'stddev': 65.83153739294727}
#         },
#         'data\\environments\\map_2021-12-30_12-41-48_vrp.json': {
#             'exec_t': {'mean': 6.79059486572559, 'stddev': 2.2539760292248827},
#             'cost_improvement': {
#                 'mean': 0.21750530999128562,
#                 'stddev': 0.025065615060612695
#             },
#             'iters': {'mean': 103.58461538461539, 'stddev': 46.3770834573064}
#         },
#         'data\\environments\\map_2021-12-30_12-39-34_vrp.json': {
#             'exec_t': {'mean': 5.940063194606616, 'stddev': 2.2526656841050623},
#             'cost_improvement': {
#                 'mean': 0.17043781274966693,
#                 'stddev': 0.023904253541467847
#             },
#             'iters': {'mean': 121.00869565217391, 'stddev': 46.330145476381794}
#         },
#         'data\\environments\\map_2021-12-30_12-38-55_vrp.json': {
#             'exec_t': {'mean': 4.911083377176715, 'stddev': 1.590782913887969},
#             'cost_improvement': {
#                 'mean': 0.15226371995729882,
#                 'stddev': 0.024399707487170564
#             },
#             'iters': {'mean': 144.04032258064515, 'stddev': 59.22472006317769}
#         },
#         'data\\environments\\map_2021-12-30_12-36-44_vrp.json': {
#             'exec_t': {'mean': 4.430200081122549, 'stddev': 1.3209688906146295},
#             'cost_improvement': {
#                 'mean': 0.15279860087004654,
#                 'stddev': 0.04404922833304648
#             },
#             'iters': {'mean': 155.58771929824562, 'stddev': 60.24372495556926}
#         }
#     }
# }
