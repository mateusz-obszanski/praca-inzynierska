# %%
from pathlib import Path
import json

# %%
from bin.rand_exp_config import generate_rand_conf
from bin.refactored_experiment import experiment_tsp
from libs.data_loading.utils import ExperimentType
from libs.data_loading.loaders import get_env_data

# %%
env_data = get_env_data(Path("data/environments/map_2021-12-15_08-57-55_tsp.json"))
conf = generate_rand_conf(
    ExperimentType.TSP,
    env_data,
    population_size=10,
    generation_n=100,
    timeout=60,
    early_stop_iters=50
)
# Out:
# before fixing: [0 4 7 8 5 1 3 6 2 0]
# [0 7 3 2 4 5 1 6 8 0]
# [0 3 1 6 5 2 7 4 8 0]
# [0 3 1 8 6 4 5 7 2 0]
# [0 8 5 4 7 6 3 1 2 0]
# [0 2 8 3 4 5 1 6 7 0]
# [0 4 3 8 1 5 7 6 2 0]
# [0 2 7 4 1 6 8 3 5 0]
# [0 2 4 7 1 8 3 6 5 0]
# [0 6 2 4 5 8 3 7 1 0]
# __fix_tsp chromosome = [0, 3, 1, 6, 5, 2, 7, 4, 8, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 1, 6, 5, 2, 7, 4, 8, 0]
# find invalid transitions solution = [0, 3, 4, 6, 5, 2, 1, 7, 8, 0]
# fixed individual 2
# __fix_tsp chromosome = [0, 3, 1, 8, 6, 4, 5, 7, 2, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 1, 8, 6, 4, 5, 7, 2, 0]
# __fix_tsp chromosome = [0, 2, 7, 5, 4, 6, 8, 1, 3, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 2, 7, 5, 4, 6, 8, 1, 3, 0]
# will regenerate individual 3
# __fix_tsp chromosome = [0, 8, 1, 7, 3, 4, 5, 6, 2, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 8, 1, 7, 3, 4, 5, 6, 2, 0]
# find invalid transitions solution = [0, 8, 1, 7, 3, 4, 5, 6, 2, 0]
# fixed individual 3
# __fix_tsp chromosome = [0, 8, 5, 4, 7, 6, 3, 1, 2, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 8, 5, 4, 7, 6, 3, 1, 2, 0]
# find invalid transitions solution = [0, 8, 5, 4, 7, 1, 3, 6, 2, 0]
# fixed individual 4
# __fix_tsp chromosome = [0, 2, 8, 3, 4, 5, 1, 6, 7, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 2, 8, 3, 4, 5, 1, 6, 7, 0]
# __fix_tsp chromosome = [0, 7, 6, 1, 5, 4, 3, 8, 2, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 6, 1, 5, 4, 3, 8, 2, 0]
# will regenerate individual 5
# __fix_tsp chromosome = [0, 2, 8, 7, 3, 1, 6, 4, 5, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 2, 8, 7, 3, 1, 6, 4, 5, 0]
# __fix_tsp chromosome = [0, 5, 4, 6, 1, 3, 7, 8, 2, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 5, 4, 6, 1, 3, 7, 8, 2, 0]
# will regenerate individual 5
# __fix_tsp chromosome = [0, 4, 6, 5, 2, 8, 1, 3, 7, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 4, 6, 5, 2, 8, 1, 3, 7, 0]
# find invalid transitions solution = [0, 4, 6, 5, 2, 8, 1, 3, 0, 7]
# fixed individual 5
# __fix_tsp chromosome = [0, 4, 3, 8, 1, 5, 7, 6, 2, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 4, 3, 8, 1, 5, 7, 6, 2, 0]
# __fix_tsp chromosome = [0, 2, 6, 7, 5, 1, 8, 3, 4, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 2, 6, 7, 5, 1, 8, 3, 4, 0]
# will regenerate individual 6
# __fix_tsp chromosome = [0, 1, 6, 5, 2, 8, 3, 7, 4, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 1, 6, 5, 2, 8, 3, 7, 4, 0]
# find invalid transitions solution = [0, 1, 6, 5, 2, 8, 3, 0, 4, 7]
# fixed individual 6
# __fix_tsp chromosome = [0, 2, 7, 4, 1, 6, 8, 3, 5, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 2, 7, 4, 1, 6, 8, 3, 5, 0]
# find invalid transitions solution = [0, 2, 4, 7, 1, 6, 8, 3, 5, 0]
# fixed individual 7
# __fix_tsp chromosome = [0, 6, 2, 4, 5, 8, 3, 7, 1, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 6, 2, 4, 5, 8, 3, 7, 1, 0]
# find invalid transitions solution = [0, 6, 2, 4, 5, 8, 3, 0, 1, 7]
# fixed individual 9
# after fixing: [0 4 7 8 5 1 3 6 2 0]
# [0 7 3 2 4 5 1 6 8 0]
# [0 3 4 6 5 2 1 7 8 0]
# [0 8 1 7 3 4 5 6 2 0]
# [0 8 5 4 7 1 3 6 2 0]
# [0 4 6 5 2 8 1 3 0 7]
# [0 1 6 5 2 8 3 0 4 7]
# [0 2 4 7 1 6 8 3 5 0]
# [0 2 4 7 1 8 3 6 5 0]
# [0 6 2 4 5 8 3 0 1 7]
# cross_kws = {'k': 4, 'inversion_p': 0.3}
# mut_kws = {<function mutate_swap at 0x0000028056B3C5E0>: {}}
# mut_ps = {<function mutate_swap at 0x0000028056B3C5E0>: 0.3}

# %%
conf_path = Path("test_experiment_config.json")
conf.save_to_json(conf_path)

# %%
results_path = "test_experiment_results.json"
experiment_tsp(
    str(conf_path),
    results_path,
    population_size=10,
    generation_n=100,
    exp_timeout=60,
    early_stop_n=50,
)
with open(results_path, "r") as f:
    d = json.loads(f.read())
    print("\n".join(f"{k}: {v}" for k, v in d.items()))
# Out:
# exp_data_to_validate['crossover_kwargs'] = {'k': 4, 'inversion_p': 0.3}
# Output()
# initial: len(costs) = 10, len(population) = 10
# #################################################
# in while: len(costs) = 10, len(population) = 10
# costs = [37.748850254513506, 38.27260666066451, 22.477165765191426, 37.748850254513506, 37.748850254513506, inf, inf, 29.1125429999232, 24.455763402057258, inf]
# attractiveness = array([-37.74885025, -38.27260666, -22.47716577, -37.74885025,
#        -37.74885025,         -inf,         -inf, -29.112543  ,
#        -24.4557634 ,         -inf])
# len(parent_costs) = 10
# crossover_kwargs = {'k': 4, 'inversion_p': 0.3}
# __fix_tsp chromosome = [0, 4, 2, 5, 2, 8, 7, 6, 4, 3]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 4, 2, 5, 2, 8, 7, 6, 4, 0]
# find invalid transitions solution = [0, 3, 4, 5, 2, 8, 7, 1, 6, 0]
# __fix_tsp chromosome = [7, 1, 6, 1, 0, 0, 3, 8, 5, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 1, 6, 1, 0, 0, 3, 8, 5, 0]
# find invalid transitions solution = [0, 1, 6, 7, 2, 4, 3, 8, 5, 0]
# __fix_tsp chromosome = [8, 6, 8, 0, 3, 5, 7, 6, 1, 7]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 6, 8, 0, 3, 5, 7, 6, 1, 0]
# find invalid transitions solution = [0, 4, 8, 0, 3, 5, 7, 2, 1, 6]
# __fix_tsp chromosome = [0, 4, 4, 2, 5, 1, 3, 0, 2, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 4, 4, 2, 5, 1, 3, 0, 2, 0]
# find invalid transitions solution = [0, 4, 7, 8, 5, 1, 3, 0, 2, 0]
# __fix_tsp chromosome = [5, 0, 4, 3, 8, 4, 1, 7, 0, 6]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 0, 4, 3, 8, 4, 1, 7, 0, 0]
# find invalid transitions solution = [0, 4, 5, 3, 8, 6, 1, 7, 2, 0]
# __fix_tsp chromosome = [0, 7, 3, 2, 5, 2, 6, 1, 0, 8]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 3, 2, 5, 2, 6, 1, 0, 0]
# find invalid transitions solution = [0, 7, 3, 4, 5, 8, 6, 1, 2, 0]
# __fix_tsp chromosome = [0, 8, 1, 2, 1, 7, 8, 6, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 8, 1, 2, 1, 7, 8, 6, 6, 0]
# find invalid transitions solution = [0, 3, 4, 2, 5, 7, 8, 6, 1, 0]
# __fix_tsp chromosome = [0, 2, 4, 7, 3, 4, 5, 3, 5, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 2, 4, 7, 3, 4, 5, 3, 5, 0]
# find invalid transitions solution = [0, 2, 5, 7, 8, 6, 3, 4, 1, 0]
# __fix_tsp chromosome = [0, 6, 4, 4, 7, 8, 3, 1, 0, 2]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 6, 4, 4, 7, 8, 3, 1, 0, 0]
# find invalid transitions solution = [0, 6, 4, 1, 7, 8, 3, 0, 2, 5]
# __fix_tsp chromosome = [0, 8, 5, 6, 2, 5, 3, 1, 0, 7]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 8, 5, 6, 2, 5, 3, 1, 0, 0]
# find invalid transitions solution = [0, 8, 5, 6, 2, 1, 3, 0, 4, 7]
# len(next_gen_costs) = 10, len(next_gen) = 10
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# i = 0----------------------------------------
# in while: len(costs) = 10, len(population) = 10
# costs = [35.14060297833601, 22.037197821590954, 22.772197580910408, 27.97062065885301, 22.477165765191426, 24.455763402057258, 25.88538456036218, 24.121974350512026, 29.1125429999232, 37.748850254513506]
# attractiveness = array([-35.14060298, -22.03719782, -22.77219758, -27.97062066,
#        -22.47716577, -24.4557634 , -25.88538456, -24.12197435,
#        -29.112543  , -37.74885025])
# len(parent_costs) = 10
# crossover_kwargs = {'k': 4, 'inversion_p': 0.3}
# __fix_tsp chromosome = [0, 2, 4, 1, 8, 5, 8, 6, 2, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 2, 4, 1, 8, 5, 8, 6, 2, 0]
# find invalid transitions solution = [0, 3, 4, 1, 2, 5, 8, 6, 7, 0]
# __fix_tsp chromosome = [0, 4, 3, 7, 5, 7, 6, 1, 3, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 4, 3, 7, 5, 7, 6, 1, 3, 0]
# find invalid transitions solution = [0, 4, 7, 8, 5, 2, 3, 1, 6, 0]
# __fix_tsp chromosome = [0, 4, 3, 3, 8, 7, 1, 2, 2, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 4, 3, 3, 8, 7, 1, 2, 2, 0]
# find invalid transitions solution = [0, 4, 3, 6, 8, 7, 1, 2, 5, 0]
# __fix_tsp chromosome = [0, 4, 5, 6, 5, 7, 1, 6, 8, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 4, 5, 6, 5, 7, 1, 6, 8, 0]
# find invalid transitions solution = [0, 4, 3, 6, 5, 7, 1, 2, 8, 0]
# __fix_tsp chromosome = [0, 2, 5, 7, 3, 8, 1, 0, 3, 4]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 2, 5, 7, 3, 8, 1, 0, 3, 0]
# find invalid transitions solution = [0, 2, 5, 7, 3, 8, 1, 4, 6, 0]
# __fix_tsp chromosome = [0, 1, 4, 7, 2, 6, 8, 6, 5, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 1, 4, 7, 2, 6, 8, 6, 5, 0]
# find invalid transitions solution = [0, 1, 4, 7, 2, 3, 8, 6, 5, 0]
# __fix_tsp chromosome = [0, 4, 7, 6, 2, 1, 3, 0, 5, 1]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 4, 7, 6, 2, 1, 3, 0, 5, 0]
# find invalid transitions solution = [0, 4, 7, 8, 2, 1, 3, 0, 5, 0]
# __fix_tsp chromosome = [0, 3, 4, 5, 8, 7, 8, 6, 2, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 4, 5, 8, 7, 8, 6, 2, 0]
# find invalid transitions solution = [0, 3, 4, 5, 8, 7, 1, 6, 2, 0]
# __fix_tsp chromosome = [0, 6, 0, 5, 1, 1, 7, 8, 6, 3]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 6, 0, 5, 1, 1, 7, 8, 6, 0]
# find invalid transitions solution = [0, 3, 0, 5, 4, 1, 7, 8, 6, 0]
# __fix_tsp chromosome = [0, 2, 8, 7, 2, 4, 4, 3, 5, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 2, 8, 7, 2, 4, 4, 3, 5, 0]
# find invalid transitions solution = [0, 1, 8, 7, 2, 4, 6, 3, 5, 0]
# len(next_gen_costs) = 10, len(next_gen) = 10
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# i = 1----------------------------------------
# in while: len(costs) = 10, len(population) = 10
# costs = [17.01975072645293, 22.772197580910408, 22.477165765191426, 22.200217432100896, 22.037197821590954, 25.88538456036218, 18.424769448086554, 24.455763402057258, 29.1125429999232, 24.121974350512026]
# attractiveness = array([-17.01975073, -22.77219758, -22.47716577, -22.20021743,
#        -22.03719782, -25.88538456, -18.42476945, -24.4557634 ,
#        -29.112543  , -24.12197435])
# len(parent_costs) = 10
# crossover_kwargs = {'k': 4, 'inversion_p': 0.3}
# __fix_tsp chromosome = [4, 0, 5, 3, 2, 8, 7, 0, 2, 7]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 0, 5, 3, 2, 8, 7, 0, 2, 0]
# find invalid transitions solution = [0, 1, 5, 3, 4, 8, 7, 2, 0, 0]
# __fix_tsp chromosome = [0, 3, 4, 5, 1, 6, 8, 1, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 4, 5, 1, 6, 8, 1, 6, 0]
# find invalid transitions solution = [0, 3, 4, 5, 2, 1, 8, 6, 7, 0]
# __fix_tsp chromosome = [0, 2, 3, 8, 1, 8, 3, 0, 6, 2]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 2, 3, 8, 1, 8, 3, 0, 6, 0]
# find invalid transitions solution = [0, 2, 5, 8, 1, 4, 7, 0, 6, 0]
# __fix_tsp chromosome = [0, 2, 0, 7, 4, 1, 8, 5, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 2, 0, 7, 4, 1, 8, 5, 6, 0]
# find invalid transitions solution = [0, 2, 0, 3, 4, 1, 8, 5, 6, 0]
# __fix_tsp chromosome = [0, 4, 7, 4, 5, 7, 1, 6, 5, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 4, 7, 4, 5, 7, 1, 6, 5, 0]
# find invalid transitions solution = [0, 3, 4, 7, 8, 5, 1, 6, 2, 0]
# __fix_tsp chromosome = [0, 4, 3, 5, 8, 7, 1, 0, 2, 6]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 4, 3, 5, 8, 7, 1, 0, 2, 0]
# find invalid transitions solution = [0, 4, 3, 5, 8, 7, 1, 6, 2, 0]
# __fix_tsp chromosome = [0, 2, 3, 8, 6, 7, 1, 4, 5, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 2, 3, 8, 6, 7, 1, 4, 5, 0]
# find invalid transitions solution = [0, 2, 3, 8, 6, 7, 1, 4, 5, 0]
# __fix_tsp chromosome = [0, 3, 6, 2, 5, 4, 1, 8, 3, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 6, 2, 5, 4, 1, 8, 3, 0]
# find invalid transitions solution = [0, 3, 6, 2, 5, 4, 1, 8, 7, 0]
# __fix_tsp chromosome = [0, 1, 4, 7, 2, 7, 8, 6, 0, 5]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 1, 4, 7, 2, 7, 8, 6, 0, 0]
# find invalid transitions solution = [0, 1, 4, 7, 2, 5, 8, 6, 0, 3]
# __fix_tsp chromosome = [0, 1, 7, 8, 1, 6, 4, 3, 0, 5]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 1, 7, 8, 1, 6, 4, 3, 0, 0]
# find invalid transitions solution = [0, 1, 7, 8, 5, 6, 4, 3, 0, 2]
# __fix_tsp chromosome = [0, 2, 4, 7, 5, 2, 3, 8, 0, 6]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 2, 4, 7, 5, 2, 3, 8, 0, 0]
# find invalid transitions solution = [0, 1, 4, 7, 5, 2, 3, 8, 0, 6]
# len(next_gen_costs) = 10, len(next_gen) = 10
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# i = 2----------------------------------------
# in while: len(costs) = 10, len(population) = 10
# costs = [25.400387227497507, 24.455763402057258, 25.88538456036218, 24.121974350512026, 29.1125429999232, 22.200217432100896, 22.200217432100896, 18.424769448086554, 22.477165765191426, 22.772197580910408]
# attractiveness = array([-25.40038723, -24.4557634 , -25.88538456, -24.12197435,
#        -29.112543  , -22.20021743, -22.20021743, -18.42476945,
#        -22.47716577, -22.77219758])
# len(parent_costs) = 10
# crossover_kwargs = {'k': 4, 'inversion_p': 0.3}
# __fix_tsp chromosome = [0, 5, 4, 7, 2, 5, 7, 1, 4, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 5, 4, 7, 2, 5, 7, 1, 4, 0]
# find invalid transitions solution = [0, 3, 4, 7, 2, 5, 8, 1, 6, 0]
# __fix_tsp chromosome = [0, 1, 8, 6, 3, 6, 3, 8, 2, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 1, 8, 6, 3, 6, 3, 8, 2, 0]
# find invalid transitions solution = [0, 1, 4, 7, 8, 5, 3, 6, 2, 0]
# __fix_tsp chromosome = [0, 3, 6, 7, 8, 5, 1, 8, 0, 2]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 6, 7, 8, 5, 1, 8, 0, 0]
# find invalid transitions solution = [0, 3, 6, 7, 8, 5, 1, 2, 0, 4]
# __fix_tsp chromosome = [1, 3, 4, 4, 5, 7, 0, 6, 2, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 4, 4, 5, 7, 0, 6, 2, 0]
# find invalid transitions solution = [0, 3, 4, 1, 5, 7, 8, 6, 2, 0]
# __fix_tsp chromosome = [0, 4, 7, 4, 7, 5, 3, 8, 0, 6]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 4, 7, 4, 7, 5, 3, 8, 0, 0]
# find invalid transitions solution = [0, 1, 2, 4, 7, 5, 3, 8, 0, 6]
# __fix_tsp chromosome = [0, 2, 8, 6, 1, 2, 1, 5, 3, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 2, 8, 6, 1, 2, 1, 5, 3, 0]
# find invalid transitions solution = [0, 1, 8, 6, 7, 2, 4, 5, 3, 0]
# __fix_tsp chromosome = [0, 1, 7, 3, 2, 3, 1, 7, 5, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 1, 7, 3, 2, 3, 1, 7, 5, 0]
# find invalid transitions solution = [0, 3, 4, 1, 2, 8, 6, 7, 5, 0]
# __fix_tsp chromosome = [0, 2, 8, 5, 8, 6, 4, 0, 6, 4]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 2, 8, 5, 8, 6, 4, 0, 6, 0]
# find invalid transitions solution = [0, 2, 1, 5, 8, 7, 4, 3, 6, 0]
# __fix_tsp chromosome = [0, 3, 4, 8, 7, 8, 2, 5, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 4, 8, 7, 8, 2, 5, 6, 0]
# find invalid transitions solution = [0, 3, 4, 1, 7, 8, 2, 5, 6, 0]
# __fix_tsp chromosome = [0, 3, 4, 5, 2, 7, 6, 0, 1, 1]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 4, 5, 2, 7, 6, 0, 1, 0]
# find invalid transitions solution = [0, 3, 4, 5, 2, 0, 6, 0, 1, 7]
# len(next_gen_costs) = 10, len(next_gen) = 10
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# i = 3----------------------------------------
# in while: len(costs) = 10, len(population) = 10
# costs = [18.424769448086554, 22.200217432100896, 22.477165765191426, 24.121974350512026, 22.200217432100896, 25.400387227497507, 22.200217432100896, 18.16895930206391, 24.455763402057258, 22.772197580910408]
# attractiveness = array([-18.42476945, -22.20021743, -22.47716577, -24.12197435,
#        -22.20021743, -25.40038723, -22.20021743, -18.1689593 ,
#        -24.4557634 , -22.77219758])
# len(parent_costs) = 10
# crossover_kwargs = {'k': 4, 'inversion_p': 0.3}
# __fix_tsp chromosome = [0, 3, 4, 4, 5, 5, 1, 3, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 4, 4, 5, 5, 1, 3, 6, 0]
# find invalid transitions solution = [0, 3, 4, 7, 8, 5, 1, 2, 6, 0]
# __fix_tsp chromosome = [0, 2, 1, 7, 8, 7, 8, 6, 2, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 2, 1, 7, 8, 7, 8, 6, 2, 0]
# find invalid transitions solution = [0, 3, 1, 2, 5, 8, 7, 6, 4, 0]
# __fix_tsp chromosome = [0, 7, 4, 1, 2, 5, 6, 3, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 4, 1, 2, 5, 6, 3, 6, 0]
# find invalid transitions solution = [0, 7, 8, 1, 2, 5, 4, 3, 6, 0]
# __fix_tsp chromosome = [7, 8, 0, 1, 8, 5, 3, 4, 0, 2]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 8, 0, 1, 8, 5, 3, 4, 0, 0]
# find invalid transitions solution = [0, 2, 0, 1, 7, 5, 3, 4, 8, 6]
# __fix_tsp chromosome = [0, 2, 4, 2, 5, 8, 6, 1, 3, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 2, 4, 2, 5, 8, 6, 1, 3, 0]
# find invalid transitions solution = [0, 2, 4, 7, 5, 8, 6, 1, 3, 0]
# __fix_tsp chromosome = [0, 3, 4, 7, 7, 8, 1, 5, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 4, 7, 7, 8, 1, 5, 6, 0]
# find invalid transitions solution = [0, 3, 4, 7, 2, 8, 1, 5, 6, 0]
# __fix_tsp chromosome = [0, 3, 6, 3, 8, 7, 1, 2, 2, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 6, 3, 8, 7, 1, 2, 2, 0]
# find invalid transitions solution = [0, 3, 6, 4, 8, 7, 1, 2, 5, 0]
# __fix_tsp chromosome = [0, 4, 7, 4, 5, 5, 1, 6, 8, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 4, 7, 4, 5, 5, 1, 6, 8, 0]
# find invalid transitions solution = [0, 3, 7, 5, 4, 2, 1, 6, 8, 0]
# __fix_tsp chromosome = [0, 7, 4, 5, 5, 6, 1, 7, 0, 2]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 4, 5, 5, 6, 1, 7, 0, 0]
# find invalid transitions solution = [0, 3, 4, 7, 8, 6, 1, 2, 5, 0]
# __fix_tsp chromosome = [0, 3, 6, 3, 8, 8, 0, 4, 2, 1]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 6, 3, 8, 8, 0, 4, 2, 0]
# find invalid transitions solution = [0, 3, 6, 7, 8, 5, 0, 4, 2, 0]
# len(next_gen_costs) = 10, len(next_gen) = 10
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# i = 4----------------------------------------
# in while: len(costs) = 10, len(population) = 10
# costs = [22.200217432100896, 22.200217432100896, 18.16895930206391, 18.424769448086554, 25.400387227497507, 25.041203438015877, 22.477165765191426, 24.121974350512026, 22.477165765191426, 12.891644050495675]
# attractiveness = array([-22.20021743, -22.20021743, -18.1689593 , -18.42476945,
#        -25.40038723, -25.04120344, -22.47716577, -24.12197435,
#        -22.47716577, -12.89164405])
# len(parent_costs) = 10
# crossover_kwargs = {'k': 4, 'inversion_p': 0.3}
# __fix_tsp chromosome = [0, 4, 7, 5, 7, 1, 3, 8, 2, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 4, 7, 5, 7, 1, 3, 8, 2, 0]
# find invalid transitions solution = [0, 4, 7, 5, 6, 1, 3, 8, 2, 0]
# __fix_tsp chromosome = [1, 3, 6, 6, 5, 4, 8, 2, 0, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 6, 6, 5, 4, 8, 2, 0, 0]
# find invalid transitions solution = [0, 3, 6, 7, 5, 4, 8, 2, 0, 1]
# __fix_tsp chromosome = [7, 0, 1, 5, 8, 4, 3, 6, 2, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 0, 1, 5, 8, 4, 3, 6, 2, 0]
# find invalid transitions solution = [0, 4, 1, 5, 8, 7, 3, 6, 2, 0]
# __fix_tsp chromosome = [0, 4, 3, 7, 8, 5, 1, 6, 2, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 4, 3, 7, 8, 5, 1, 6, 2, 0]
# __fix_tsp chromosome = [0, 2, 6, 1, 5, 8, 7, 3, 4, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 2, 6, 1, 5, 8, 7, 3, 4, 0]
# __fix_tsp chromosome = [0, 4, 4, 7, 6, 8, 2, 1, 2, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 4, 4, 7, 6, 8, 2, 1, 2, 0]
# find invalid transitions solution = [0, 3, 4, 7, 5, 8, 6, 1, 2, 0]
# __fix_tsp chromosome = [0, 3, 5, 3, 5, 8, 1, 7, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 5, 3, 5, 8, 1, 7, 6, 0]
# find invalid transitions solution = [0, 3, 4, 5, 6, 8, 1, 7, 2, 0]
# __fix_tsp chromosome = [0, 1, 2, 5, 8, 0, 8, 4, 6, 7]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 1, 2, 5, 8, 0, 8, 4, 6, 0]
# find invalid transitions solution = [0, 1, 2, 5, 8, 0, 3, 4, 6, 0]
# __fix_tsp chromosome = [0, 7, 1, 4, 3, 5, 2, 3, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 1, 4, 3, 5, 2, 3, 6, 0]
# find invalid transitions solution = [0, 7, 1, 4, 3, 5, 2, 8, 6, 0]
# __fix_tsp chromosome = [0, 7, 8, 7, 5, 5, 4, 6, 8, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 8, 7, 5, 5, 4, 6, 8, 0]
# find invalid transitions solution = [0, 3, 5, 8, 7, 1, 4, 6, 2, 0]
# __fix_tsp chromosome = [6, 3, 4, 1, 0, 2, 1, 3, 0, 2]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 4, 1, 0, 2, 1, 3, 0, 0]
# find invalid transitions solution = [0, 3, 4, 1, 5, 2, 0, 6, 0, 7]
# len(next_gen_costs) = 10, len(next_gen) = 10
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# i = 5----------------------------------------
# in while: len(costs) = 10, len(population) = 10
# costs = [28.313403722349392, 22.200217432100896, 24.121974350512026, 24.121974350512026, 22.200217432100896, 25.041203438015877, 18.424769448086554, 22.200217432100896, 12.891644050495675, 22.477165765191426]
# attractiveness = array([-28.31340372, -22.20021743, -24.12197435, -24.12197435,
#        -22.20021743, -25.04120344, -18.42476945, -22.20021743,
#        -12.89164405, -22.47716577])
# len(parent_costs) = 10
# crossover_kwargs = {'k': 4, 'inversion_p': 0.3}
# __fix_tsp chromosome = [0, 3, 1, 4, 8, 5, 8, 2, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 1, 4, 8, 5, 8, 2, 6, 0]
# find invalid transitions solution = [0, 3, 8, 4, 1, 5, 7, 2, 6, 0]
# __fix_tsp chromosome = [7, 2, 4, 7, 3, 5, 6, 1, 0, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 2, 4, 7, 3, 5, 6, 1, 0, 0]
# find invalid transitions solution = [0, 2, 4, 7, 3, 5, 6, 1, 8, 0]
# __fix_tsp chromosome = [4, 0, 4, 0, 8, 2, 7, 2, 7, 1]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 0, 4, 0, 8, 2, 7, 2, 7, 0]
# find invalid transitions solution = [0, 3, 4, 1, 8, 5, 2, 0, 6, 7]
# __fix_tsp chromosome = [0, 3, 6, 6, 5, 5, 1, 3, 8, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 6, 6, 5, 5, 1, 3, 8, 0]
# find invalid transitions solution = [0, 3, 4, 7, 5, 2, 1, 6, 8, 0]
# __fix_tsp chromosome = [0, 4, 1, 3, 8, 6, 3, 0, 2, 7]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 4, 1, 3, 8, 6, 3, 0, 2, 0]
# find invalid transitions solution = [0, 4, 1, 5, 8, 6, 3, 0, 2, 0]
# __fix_tsp chromosome = [0, 4, 5, 8, 5, 7, 1, 6, 2, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 4, 5, 8, 5, 7, 1, 6, 2, 0]
# find invalid transitions solution = [0, 4, 3, 8, 5, 7, 1, 6, 2, 0]
# __fix_tsp chromosome = [0, 3, 4, 5, 1, 8, 6, 6, 2, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 4, 5, 1, 8, 6, 6, 2, 0]
# find invalid transitions solution = [0, 3, 4, 5, 1, 8, 6, 7, 2, 0]
# __fix_tsp chromosome = [7, 3, 4, 5, 1, 0, 0, 8, 2, 7]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 4, 5, 1, 0, 0, 8, 2, 0]
# find invalid transitions solution = [0, 3, 4, 5, 1, 6, 7, 8, 2, 0]
# __fix_tsp chromosome = [1, 4, 8, 1, 5, 2, 0, 3, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 4, 8, 1, 5, 2, 0, 3, 6, 0]
# find invalid transitions solution = [0, 4, 8, 1, 5, 2, 0, 3, 6, 0]
# __fix_tsp chromosome = [0, 7, 7, 8, 3, 5, 2, 4, 0, 6]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 7, 8, 3, 5, 2, 4, 0, 0]
# find invalid transitions solution = [0, 1, 7, 8, 3, 5, 2, 4, 6, 0]
# len(next_gen_costs) = 10, len(next_gen) = 10
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# i = 6----------------------------------------
# in while: len(costs) = 10, len(population) = 10
# costs = [12.891644050495675, 22.200217432100896, 26.962960356427008, 22.477165765191426, 24.121974350512026, 22.200217432100896, 25.400387227497507, 22.200217432100896, 24.121974350512026, 28.313403722349392]
# attractiveness = array([-12.89164405, -22.20021743, -26.96296036, -22.47716577,
#        -24.12197435, -22.20021743, -25.40038723, -22.20021743,
#        -24.12197435, -28.31340372])
# len(parent_costs) = 10
# crossover_kwargs = {'k': 4, 'inversion_p': 0.3}
# __fix_tsp chromosome = [0, 7, 8, 3, 1, 5, 6, 2, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 8, 3, 1, 5, 6, 2, 6, 0]
# find invalid transitions solution = [0, 7, 8, 3, 4, 5, 1, 2, 6, 0]
# __fix_tsp chromosome = [0, 5, 8, 7, 1, 4, 3, 4, 2, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 5, 8, 7, 1, 4, 3, 4, 2, 0]
# find invalid transitions solution = [0, 5, 8, 7, 1, 4, 3, 6, 2, 0]
# __fix_tsp chromosome = [5, 7, 3, 6, 5, 0, 2, 8, 0, 8]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 3, 6, 5, 0, 2, 8, 0, 0]
# find invalid transitions solution = [0, 7, 3, 6, 5, 0, 2, 8, 0, 1]
# __fix_tsp chromosome = [0, 4, 1, 4, 3, 2, 1, 7, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 4, 1, 4, 3, 2, 1, 7, 6, 0]
# find invalid transitions solution = [0, 1, 4, 5, 3, 2, 6, 7, 8, 0]
# __fix_tsp chromosome = [0, 4, 5, 7, 5, 3, 1, 7, 0, 2]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 4, 5, 7, 5, 3, 1, 7, 0, 0]
# find invalid transitions solution = [0, 4, 1, 2, 5, 3, 6, 7, 8, 0]
# __fix_tsp chromosome = [4, 0, 3, 8, 8, 6, 1, 6, 0, 2]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 0, 3, 8, 8, 6, 1, 6, 0, 0]
# find invalid transitions solution = [0, 4, 3, 6, 7, 8, 1, 2, 0, 5]
# __fix_tsp chromosome = [0, 8, 8, 7, 6, 5, 4, 7, 2, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 8, 8, 7, 6, 5, 4, 7, 2, 0]
# find invalid transitions solution = [0, 3, 6, 7, 8, 5, 4, 1, 2, 0]
# __fix_tsp chromosome = [0, 3, 4, 1, 2, 0, 5, 1, 6, 3]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 4, 1, 2, 0, 5, 1, 6, 0]
# find invalid transitions solution = [0, 3, 4, 1, 2, 0, 5, 8, 6, 0]
# __fix_tsp chromosome = [3, 0, 4, 8, 1, 5, 6, 1, 2, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 0, 4, 8, 1, 5, 6, 1, 2, 0]
# find invalid transitions solution = [0, 3, 4, 8, 7, 5, 6, 0, 2, 0]
# __fix_tsp chromosome = [0, 4, 3, 5, 8, 7, 6, 7, 2, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 4, 3, 5, 8, 7, 6, 7, 2, 0]
# find invalid transitions solution = [0, 4, 3, 5, 8, 7, 1, 6, 2, 0]
# len(next_gen_costs) = 10, len(next_gen) = 10
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# i = 7----------------------------------------
# in while: len(costs) = 10, len(population) = 10
# costs = [26.962960356427008, 22.200217432100896, 24.121974350512026, 22.477165765191426, 25.041203438015877, 12.891644050495675, 22.200217432100896, 25.400387227497507, 28.313403722349392, 22.200217432100896]
# attractiveness = array([-26.96296036, -22.20021743, -24.12197435, -22.47716577,
#        -25.04120344, -12.89164405, -22.20021743, -25.40038723,
#        -28.31340372, -22.20021743])
# len(parent_costs) = 10
# crossover_kwargs = {'k': 4, 'inversion_p': 0.3}
# __fix_tsp chromosome = [0, 3, 5, 4, 1, 5, 8, 0, 2, 7]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 5, 4, 1, 5, 8, 0, 2, 0]
# find invalid transitions solution = [0, 3, 6, 4, 1, 5, 8, 0, 2, 0]
# __fix_tsp chromosome = [0, 3, 8, 7, 0, 6, 1, 6, 2, 4]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 8, 7, 0, 6, 1, 6, 2, 0]
# find invalid transitions solution = [0, 3, 8, 7, 5, 4, 1, 6, 2, 0]
# __fix_tsp chromosome = [0, 1, 7, 5, 8, 8, 2, 7, 2, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 1, 7, 5, 8, 8, 2, 7, 2, 0]
# find invalid transitions solution = [0, 1, 2, 5, 8, 7, 3, 4, 6, 0]
# __fix_tsp chromosome = [0, 3, 3, 5, 0, 4, 6, 1, 6, 4]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 3, 5, 0, 4, 6, 1, 6, 0]
# find invalid transitions solution = [0, 3, 6, 5, 0, 4, 7, 1, 2, 0]
# __fix_tsp chromosome = [0, 7, 6, 3, 2, 5, 2, 1, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 6, 3, 2, 5, 2, 1, 6, 0]
# find invalid transitions solution = [0, 7, 8, 3, 4, 5, 2, 1, 6, 0]
# __fix_tsp chromosome = [8, 4, 0, 1, 5, 7, 3, 4, 8, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 4, 0, 1, 5, 7, 3, 4, 8, 0]
# find invalid transitions solution = [0, 4, 2, 1, 5, 7, 3, 6, 8, 0]
# __fix_tsp chromosome = [0, 3, 8, 5, 8, 5, 4, 2, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 8, 5, 8, 5, 4, 2, 6, 0]
# find invalid transitions solution = [0, 3, 5, 8, 7, 1, 4, 2, 6, 0]
# __fix_tsp chromosome = [1, 3, 6, 7, 7, 4, 0, 1, 2, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 6, 7, 7, 4, 0, 1, 2, 0]
# find invalid transitions solution = [0, 3, 6, 7, 8, 5, 4, 1, 2, 0]
# __fix_tsp chromosome = [0, 2, 8, 3, 1, 6, 1, 2, 0, 3]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 2, 8, 3, 1, 6, 1, 2, 0, 0]
# find invalid transitions solution = [0, 1, 8, 3, 4, 6, 7, 5, 0, 2]
# __fix_tsp chromosome = [0, 7, 5, 4, 4, 5, 7, 8, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 5, 4, 4, 5, 7, 8, 6, 0]
# find invalid transitions solution = [0, 3, 4, 1, 2, 5, 7, 8, 6, 0]
# len(next_gen_costs) = 10, len(next_gen) = 10
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# i = 8----------------------------------------
# in while: len(costs) = 10, len(population) = 10
# costs = [18.86258898023499, 22.200217432100896, 26.680624610260942, 12.891644050495675, 25.400387227497507, 25.041203438015877, 18.474220439498712, 22.200217432100896, 24.27921803717802, 24.121974350512026]
# attractiveness = array([-18.86258898, -22.20021743, -26.68062461, -12.89164405,
#        -25.40038723, -25.04120344, -18.47422044, -22.20021743,
#        -24.27921804, -24.12197435])
# len(parent_costs) = 10
# crossover_kwargs = {'k': 4, 'inversion_p': 0.3}
# __fix_tsp chromosome = [0, 4, 8, 4, 3, 5, 7, 1, 2, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 4, 8, 4, 3, 5, 7, 1, 2, 0]
# find invalid transitions solution = [0, 4, 8, 6, 3, 5, 7, 1, 2, 0]
# __fix_tsp chromosome = [0, 3, 8, 7, 6, 5, 1, 6, 2, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 8, 7, 6, 5, 1, 6, 2, 0]
# __fix_tsp chromosome = [0, 2, 6, 1, 5, 6, 7, 8, 3, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 2, 6, 1, 5, 6, 7, 8, 3, 0]
# find invalid transitions solution = [0, 2, 4, 1, 5, 7, 6, 8, 3, 0]
# __fix_tsp chromosome = [0, 4, 5, 2, 6, 1, 1, 7, 3, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 4, 5, 2, 6, 1, 1, 7, 3, 0]
# find invalid transitions solution = [0, 4, 5, 2, 6, 8, 1, 7, 3, 0]
# __fix_tsp chromosome = [0, 5, 7, 3, 0, 6, 4, 8, 8, 2]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 5, 7, 3, 0, 6, 4, 8, 8, 0]
# find invalid transitions solution = [0, 5, 7, 3, 0, 6, 4, 1, 2, 0]
# __fix_tsp chromosome = [0, 3, 4, 3, 4, 5, 7, 1, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 4, 3, 4, 5, 7, 1, 6, 0]
# find invalid transitions solution = [0, 3, 4, 8, 2, 5, 7, 1, 6, 0]
# __fix_tsp chromosome = [0, 7, 8, 8, 2, 5, 2, 1, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 8, 8, 2, 5, 2, 1, 6, 0]
# find invalid transitions solution = [0, 7, 8, 2, 4, 5, 3, 1, 6, 0]
# __fix_tsp chromosome = [0, 3, 5, 1, 5, 7, 2, 4, 8, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 5, 1, 5, 7, 2, 4, 8, 0]
# find invalid transitions solution = [0, 3, 6, 1, 5, 7, 2, 4, 8, 0]
# __fix_tsp chromosome = [3, 4, 2, 6, 7, 1, 6, 8, 0, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 4, 2, 6, 7, 1, 6, 8, 0, 0]
# find invalid transitions solution = [0, 4, 2, 5, 7, 1, 3, 8, 0, 6]
# __fix_tsp chromosome = [8, 4, 7, 5, 4, 3, 3, 0, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 4, 7, 5, 4, 3, 3, 0, 6, 0]
# find invalid transitions solution = [0, 3, 7, 5, 8, 2, 1, 0, 6, 0]
# __fix_tsp chromosome = [0, 3, 0, 1, 7, 8, 5, 2, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 0, 1, 7, 8, 5, 2, 6, 0]
# __fix_tsp chromosome = [0, 7, 8, 5, 2, 6, 1, 2, 1, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 8, 5, 2, 6, 1, 2, 1, 0]
# find invalid transitions solution = [0, 7, 8, 5, 4, 6, 3, 0, 1, 2]
# len(next_gen_costs) = 10, len(next_gen) = 10
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# i = 9----------------------------------------
# in while: len(costs) = 10, len(population) = 10
# costs = [12.891644050495675, 16.79072876508975, 24.53078856415673, 22.200217432100896, 12.891644050495675, 18.86258898023499, 25.400387227497507, 16.24761642898487, 24.121974350512026, 25.06820849793854]
# attractiveness = array([-12.89164405, -16.79072877, -24.53078856, -22.20021743,
#        -12.89164405, -18.86258898, -25.40038723, -16.24761643,
#        -24.12197435, -25.0682085 ])
# len(parent_costs) = 10
# crossover_kwargs = {'k': 4, 'inversion_p': 0.3}
# __fix_tsp chromosome = [0, 7, 8, 2, 5, 8, 3, 4, 0, 2]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 8, 2, 5, 8, 3, 4, 0, 0]
# find invalid transitions solution = [0, 7, 8, 2, 5, 1, 3, 4, 6, 0]
# __fix_tsp chromosome = [0, 7, 0, 3, 5, 1, 1, 6, 6, 4]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 0, 3, 5, 1, 1, 6, 6, 0]
# find invalid transitions solution = [0, 7, 8, 3, 5, 4, 1, 2, 0, 0]
# __fix_tsp chromosome = [0, 3, 2, 8, 4, 6, 0, 1, 7, 1]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 2, 8, 4, 6, 0, 1, 7, 0]
# find invalid transitions solution = [0, 3, 2, 8, 0, 6, 0, 1, 7, 5]
# __fix_tsp chromosome = [5, 5, 4, 3, 2, 0, 7, 8, 0, 6]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 5, 4, 3, 2, 0, 7, 8, 0, 0]
# find invalid transitions solution = [0, 5, 4, 3, 2, 0, 7, 8, 0, 1]
# __fix_tsp chromosome = [0, 3, 8, 3, 5, 7, 2, 4, 0, 2]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 8, 3, 5, 7, 2, 4, 0, 0]
# find invalid transitions solution = [0, 3, 8, 1, 5, 7, 2, 4, 6, 0]
# __fix_tsp chromosome = [0, 4, 6, 1, 5, 6, 1, 7, 8, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 4, 6, 1, 5, 6, 1, 7, 8, 0]
# find invalid transitions solution = [0, 4, 1, 2, 5, 3, 6, 7, 8, 0]
# __fix_tsp chromosome = [7, 3, 8, 1, 4, 5, 4, 0, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 8, 1, 4, 5, 4, 0, 6, 0]
# find invalid transitions solution = [0, 3, 8, 1, 2, 5, 4, 7, 6, 0]
# __fix_tsp chromosome = [0, 3, 8, 1, 2, 5, 2, 0, 7, 6]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 8, 1, 2, 5, 2, 0, 7, 0]
# find invalid transitions solution = [0, 3, 8, 1, 4, 5, 0, 0, 7, 2]
# __fix_tsp chromosome = [2, 4, 0, 0, 5, 7, 1, 8, 3, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 4, 0, 0, 5, 7, 1, 8, 3, 0]
# find invalid transitions solution = [0, 2, 0, 6, 5, 7, 1, 8, 3, 0]
# __fix_tsp chromosome = [0, 3, 8, 1, 4, 5, 2, 1, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 8, 1, 4, 5, 2, 1, 6, 0]
# find invalid transitions solution = [0, 3, 8, 7, 4, 5, 2, 1, 6, 0]
# __fix_tsp chromosome = [0, 8, 7, 6, 7, 5, 4, 3, 0, 2]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 8, 7, 6, 7, 5, 4, 3, 0, 0]
# find invalid transitions solution = [0, 8, 7, 1, 2, 5, 4, 3, 0, 6]
# len(next_gen_costs) = 10, len(next_gen) = 10
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# i = 10----------------------------------------
# in while: len(costs) = 10, len(population) = 10
# costs = [12.891644050495675, 18.86258898023499, 12.891644050495675, 24.53078856415673, 16.79072876508975, 22.477165765191426, 16.24761642898487, 25.094430039056704, 22.200217432100896, 18.86258898023499]
# attractiveness = array([-12.89164405, -18.86258898, -12.89164405, -24.53078856,
#        -16.79072877, -22.47716577, -16.24761643, -25.09443004,
#        -22.20021743, -18.86258898])
# len(parent_costs) = 10
# crossover_kwargs = {'k': 4, 'inversion_p': 0.3}
# __fix_tsp chromosome = [0, 8, 6, 3, 4, 5, 7, 4, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 8, 6, 3, 4, 5, 7, 4, 6, 0]
# find invalid transitions solution = [0, 8, 6, 3, 4, 5, 7, 1, 2, 0]
# __fix_tsp chromosome = [0, 7, 8, 5, 2, 1, 2, 1, 0, 3]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 8, 5, 2, 1, 2, 1, 0, 0]
# find invalid transitions solution = [0, 7, 8, 5, 4, 1, 2, 0, 3, 6]
# __fix_tsp chromosome = [0, 1, 6, 2, 2, 5, 7, 7, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 1, 6, 2, 2, 5, 7, 7, 6, 0]
# find invalid transitions solution = [0, 1, 2, 4, 7, 5, 8, 6, 3, 0]
# __fix_tsp chromosome = [0, 4, 8, 1, 5, 4, 3, 3, 0, 8]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 4, 8, 1, 5, 4, 3, 3, 0, 0]
# find invalid transitions solution = [0, 3, 8, 1, 5, 4, 7, 2, 0, 6]
# __fix_tsp chromosome = [0, 7, 8, 8, 2, 3, 5, 1, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 8, 8, 2, 3, 5, 1, 6, 0]
# __fix_tsp chromosome = [0, 6, 1, 5, 3, 2, 8, 8, 7, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 6, 1, 5, 3, 2, 8, 8, 7, 0]
# find invalid transitions solution = [0, 6, 1, 5, 3, 2, 8, 4, 7, 0]
# __fix_tsp chromosome = [0, 3, 4, 4, 2, 1, 7, 0, 6, 5]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 4, 4, 2, 1, 7, 0, 6, 0]
# find invalid transitions solution = [0, 3, 4, 5, 2, 1, 7, 8, 6, 0]
# __fix_tsp chromosome = [0, 3, 6, 7, 8, 7, 2, 4, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 6, 7, 8, 7, 2, 4, 6, 0]
# find invalid transitions solution = [0, 3, 6, 7, 8, 5, 2, 4, 1, 0]
# __fix_tsp chromosome = [8, 3, 4, 1, 5, 5, 2, 1, 0, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 4, 1, 5, 5, 2, 1, 0, 0]
# find invalid transitions solution = [0, 3, 4, 1, 5, 8, 2, 0, 6, 7]
# __fix_tsp chromosome = [0, 3, 6, 7, 8, 4, 7, 5, 0, 2]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 6, 7, 8, 4, 7, 5, 0, 0]
# find invalid transitions solution = [0, 3, 6, 7, 8, 2, 1, 5, 0, 4]
# __fix_tsp chromosome = [0, 1, 8, 0, 3, 5, 4, 1, 6, 2]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 1, 8, 0, 3, 5, 4, 1, 6, 0]
# find invalid transitions solution = [0, 1, 8, 0, 3, 5, 4, 7, 6, 0]
# len(next_gen_costs) = 10, len(next_gen) = 10
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# i = 11----------------------------------------
# in while: len(costs) = 10, len(population) = 10
# costs = [12.891644050495675, 16.79072876508975, 12.891644050495675, 16.24761642898487, 22.200217432100896, 18.86258898023499, 27.526541633431393, 28.313403722349392, 27.57840396302994, 22.477165765191426]
# attractiveness = array([-12.89164405, -16.79072877, -12.89164405, -16.24761643,
#        -22.20021743, -18.86258898, -27.52654163, -28.31340372,
#        -27.57840396, -22.47716577])
# len(parent_costs) = 10
# crossover_kwargs = {'k': 4, 'inversion_p': 0.3}
# __fix_tsp chromosome = [0, 7, 4, 2, 2, 5, 6, 8, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 4, 2, 2, 5, 6, 8, 6, 0]
# find invalid transitions solution = [0, 7, 3, 4, 1, 5, 2, 8, 6, 0]
# __fix_tsp chromosome = [0, 1, 3, 1, 7, 8, 4, 5, 3, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 1, 3, 1, 7, 8, 4, 5, 3, 0]
# find invalid transitions solution = [0, 3, 4, 1, 7, 8, 6, 5, 2, 0]
# __fix_tsp chromosome = [0, 3, 4, 5, 2, 5, 7, 1, 8, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 4, 5, 2, 5, 7, 1, 8, 0]
# find invalid transitions solution = [0, 3, 4, 5, 2, 6, 7, 1, 8, 0]
# __fix_tsp chromosome = [6, 4, 7, 8, 6, 2, 1, 3, 0, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 4, 7, 8, 6, 2, 1, 3, 0, 0]
# find invalid transitions solution = [0, 4, 7, 8, 6, 2, 1, 3, 0, 5]
# __fix_tsp chromosome = [0, 8, 7, 5, 4, 2, 4, 3, 0, 3]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 8, 7, 5, 4, 2, 4, 3, 0, 0]
# find invalid transitions solution = [0, 8, 7, 5, 4, 2, 1, 3, 0, 6]
# __fix_tsp chromosome = [1, 8, 6, 2, 0, 5, 1, 7, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 8, 6, 2, 0, 5, 1, 7, 6, 0]
# find invalid transitions solution = [0, 8, 6, 2, 0, 5, 1, 7, 3, 0]
# __fix_tsp chromosome = [3, 0, 8, 1, 8, 5, 4, 3, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 0, 8, 1, 8, 5, 4, 3, 6, 0]
# find invalid transitions solution = [0, 2, 0, 1, 7, 5, 4, 3, 6, 0]
# __fix_tsp chromosome = [0, 7, 2, 6, 7, 5, 4, 1, 2, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 2, 6, 7, 5, 4, 1, 2, 0]
# find invalid transitions solution = [0, 3, 2, 6, 7, 5, 4, 1, 8, 0]
# __fix_tsp chromosome = [0, 8, 7, 5, 2, 5, 2, 8, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 8, 7, 5, 2, 5, 2, 8, 6, 0]
# find invalid transitions solution = [0, 3, 7, 8, 5, 4, 1, 2, 6, 0]
# __fix_tsp chromosome = [0, 6, 4, 3, 4, 1, 7, 0, 3, 1]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 6, 4, 3, 4, 1, 7, 0, 3, 0]
# find invalid transitions solution = [0, 6, 3, 4, 5, 1, 7, 8, 2, 0]
# len(next_gen_costs) = 10, len(next_gen) = 10
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# i = 12----------------------------------------
# in while: len(costs) = 10, len(population) = 10
# costs = [16.79072876508975, 22.200217432100896, 12.891644050495675, 25.041203438015877, 27.526541633431393, 22.477165765191426, 18.86258898023499, 12.891644050495675, 28.313403722349392, 16.24761642898487]
# attractiveness = array([-16.79072877, -22.20021743, -12.89164405, -25.04120344,
#        -27.52654163, -22.47716577, -18.86258898, -12.89164405,
#        -28.31340372, -16.24761643])
# len(parent_costs) = 10
# crossover_kwargs = {'k': 4, 'inversion_p': 0.3}
# __fix_tsp chromosome = [4, 7, 8, 5, 2, 5, 0, 3, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 8, 5, 2, 5, 0, 3, 6, 0]
# find invalid transitions solution = [0, 7, 8, 5, 2, 1, 0, 3, 6, 0]
# __fix_tsp chromosome = [0, 2, 3, 0, 1, 6, 5, 8, 7, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 2, 3, 0, 1, 6, 5, 8, 7, 0]
# __fix_tsp chromosome = [0, 4, 3, 2, 1, 1, 7, 0, 6, 8]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 4, 3, 2, 1, 1, 7, 0, 6, 0]
# find invalid transitions solution = [0, 4, 3, 2, 5, 8, 7, 1, 6, 0]
# __fix_tsp chromosome = [0, 2, 8, 7, 4, 6, 3, 4, 5, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 2, 8, 7, 4, 6, 3, 4, 5, 0]
# find invalid transitions solution = [0, 2, 8, 7, 1, 6, 3, 4, 5, 0]
# __fix_tsp chromosome = [0, 7, 8, 3, 1, 5, 2, 1, 0, 6]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 8, 3, 1, 5, 2, 1, 0, 0]
# find invalid transitions solution = [0, 7, 8, 3, 4, 5, 2, 1, 6, 0]
# __fix_tsp chromosome = [0, 0, 4, 3, 4, 5, 1, 2, 2, 3]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 0, 4, 3, 4, 5, 1, 2, 2, 0]
# find invalid transitions solution = [0, 4, 7, 3, 6, 5, 1, 2, 0, 0]
# __fix_tsp chromosome = [0, 8, 6, 8, 7, 7, 5, 1, 0, 6]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 8, 6, 8, 7, 7, 5, 1, 0, 0]
# find invalid transitions solution = [0, 3, 6, 7, 8, 0, 5, 1, 2, 4]
# __fix_tsp chromosome = [0, 3, 4, 2, 1, 5, 7, 1, 0, 6]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 4, 2, 1, 5, 7, 1, 0, 0]
# find invalid transitions solution = [0, 3, 4, 2, 1, 5, 7, 8, 6, 0]
# __fix_tsp chromosome = [0, 7, 8, 8, 2, 5, 4, 3, 0, 6]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 8, 8, 2, 5, 4, 3, 0, 0]
# find invalid transitions solution = [0, 7, 8, 6, 2, 5, 4, 3, 0, 1]
# __fix_tsp chromosome = [0, 4, 1, 7, 8, 5, 6, 7, 2, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 4, 1, 7, 8, 5, 6, 7, 2, 0]
# find invalid transitions solution = [0, 4, 1, 3, 8, 5, 6, 7, 2, 0]
# __fix_tsp chromosome = [5, 3, 4, 3, 6, 2, 0, 1, 0, 8]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 4, 3, 6, 2, 0, 1, 0, 0]
# find invalid transitions solution = [0, 3, 4, 7, 6, 2, 0, 1, 5, 8]
# len(next_gen_costs) = 10, len(next_gen) = 10
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# i = 13----------------------------------------
# in while: len(costs) = 10, len(population) = 10
# costs = [17.475040558814257, 12.891644050495675, 16.24761642898487, 25.041203438015877, 16.24761642898487, 16.79072876508975, 12.891644050495675, 22.477165765191426, 12.891644050495675, 18.86258898023499]
# attractiveness = array([-17.47504056, -12.89164405, -16.24761643, -25.04120344,
#        -16.24761643, -16.79072877, -12.89164405, -22.47716577,
#        -12.89164405, -18.86258898])
# len(parent_costs) = 10
# crossover_kwargs = {'k': 4, 'inversion_p': 0.3}
# __fix_tsp chromosome = [3, 0, 5, 2, 7, 4, 1, 0, 6, 8]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 0, 5, 2, 7, 4, 1, 0, 6, 0]
# find invalid transitions solution = [0, 3, 5, 2, 4, 7, 1, 8, 6, 0]
# __fix_tsp chromosome = [0, 3, 4, 8, 1, 5, 7, 2, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 4, 8, 1, 5, 7, 2, 6, 0]
# find invalid transitions solution = [0, 3, 4, 8, 1, 5, 7, 2, 6, 0]
# __fix_tsp chromosome = [0, 3, 2, 1, 2, 5, 7, 7, 8, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 2, 1, 2, 5, 7, 7, 8, 0]
# find invalid transitions solution = [0, 3, 4, 1, 2, 5, 6, 7, 8, 0]
# __fix_tsp chromosome = [0, 4, 4, 8, 6, 5, 3, 1, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 4, 4, 8, 6, 5, 3, 1, 6, 0]
# find invalid transitions solution = [0, 1, 2, 8, 7, 5, 3, 4, 6, 0]
# __fix_tsp chromosome = [0, 7, 1, 8, 2, 5, 3, 4, 0, 6]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 1, 8, 2, 5, 3, 4, 0, 0]
# find invalid transitions solution = [0, 7, 1, 8, 2, 5, 3, 4, 6, 0]
# __fix_tsp chromosome = [0, 7, 8, 1, 2, 5, 4, 3, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 8, 1, 2, 5, 4, 3, 6, 0]
# find invalid transitions solution = [0, 7, 8, 1, 2, 5, 4, 3, 6, 0]
# __fix_tsp chromosome = [5, 3, 8, 7, 0, 1, 2, 1, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 8, 7, 0, 1, 2, 1, 6, 0]
# find invalid transitions solution = [0, 3, 8, 7, 5, 4, 2, 1, 6, 0]
# __fix_tsp chromosome = [8, 0, 4, 7, 4, 5, 3, 2, 0, 6]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 0, 4, 7, 4, 5, 3, 2, 0, 0]
# find invalid transitions solution = [0, 1, 4, 7, 8, 5, 3, 2, 0, 6]
# __fix_tsp chromosome = [0, 4, 3, 1, 5, 8, 4, 8, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 4, 3, 1, 5, 8, 4, 8, 6, 0]
# find invalid transitions solution = [0, 1, 3, 4, 5, 8, 7, 2, 6, 0]
# __fix_tsp chromosome = [0, 7, 3, 2, 5, 6, 7, 2, 1, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 3, 2, 5, 6, 7, 2, 1, 0]
# find invalid transitions solution = [0, 4, 3, 0, 5, 6, 7, 8, 1, 2]
# len(next_gen_costs) = 10, len(next_gen) = 10
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# i = 14----------------------------------------
# in while: len(costs) = 10, len(population) = 10
# costs = [25.041203438015877, 25.041203438015877, 12.891644050495675, 16.24761642898487, 16.24761642898487, 12.891644050495675, 23.87362589912844, 26.876222937297097, 12.891644050495675, 12.891644050495675]
# attractiveness = array([-25.04120344, -25.04120344, -12.89164405, -16.24761643,
#        -16.24761643, -12.89164405, -23.8736259 , -26.87622294,
#        -12.89164405, -12.89164405])
# len(parent_costs) = 10
# crossover_kwargs = {'k': 4, 'inversion_p': 0.3}
# __fix_tsp chromosome = [0, 6, 3, 4, 2, 5, 3, 2, 1, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 6, 3, 4, 2, 5, 3, 2, 1, 0]
# find invalid transitions solution = [0, 6, 3, 4, 7, 5, 8, 0, 1, 2]
# __fix_tsp chromosome = [0, 7, 1, 8, 5, 8, 7, 4, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 1, 8, 5, 8, 7, 4, 6, 0]
# find invalid transitions solution = [0, 3, 1, 2, 5, 4, 7, 8, 6, 0]
# __fix_tsp chromosome = [7, 4, 4, 8, 1, 5, 0, 3, 0, 6]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 4, 4, 8, 1, 5, 0, 3, 0, 0]
# find invalid transitions solution = [0, 4, 7, 8, 1, 5, 0, 3, 0, 2]
# __fix_tsp chromosome = [3, 0, 8, 1, 2, 5, 7, 2, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 0, 8, 1, 2, 5, 7, 2, 6, 0]
# find invalid transitions solution = [0, 3, 8, 1, 4, 5, 7, 2, 6, 0]
# __fix_tsp chromosome = [0, 7, 8, 8, 7, 5, 4, 3, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 8, 8, 7, 5, 4, 3, 6, 0]
# find invalid transitions solution = [0, 1, 2, 8, 7, 5, 4, 3, 6, 0]
# __fix_tsp chromosome = [0, 1, 2, 1, 2, 5, 3, 4, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 1, 2, 1, 2, 5, 3, 4, 6, 0]
# find invalid transitions solution = [0, 1, 2, 8, 7, 5, 3, 4, 6, 0]
# __fix_tsp chromosome = [0, 4, 3, 5, 2, 1, 7, 1, 0, 6]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 4, 3, 5, 2, 1, 7, 1, 0, 0]
# find invalid transitions solution = [0, 4, 3, 5, 2, 1, 7, 8, 6, 0]
# __fix_tsp chromosome = [0, 2, 7, 8, 3, 5, 4, 8, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 2, 7, 8, 3, 5, 4, 8, 6, 0]
# find invalid transitions solution = [0, 2, 1, 7, 3, 5, 4, 8, 6, 0]
# __fix_tsp chromosome = [5, 3, 8, 5, 2, 0, 4, 7, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 8, 5, 2, 0, 4, 7, 6, 0]
# find invalid transitions solution = [0, 3, 8, 5, 2, 0, 4, 7, 1, 0]
# __fix_tsp chromosome = [4, 0, 1, 2, 1, 8, 7, 3, 0, 6]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 0, 1, 2, 1, 8, 7, 3, 0, 0]
# find invalid transitions solution = [0, 1, 4, 2, 5, 8, 7, 3, 0, 6]
# len(next_gen_costs) = 10, len(next_gen) = 10
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# i = 15----------------------------------------
# in while: len(costs) = 10, len(population) = 10
# costs = [25.041203438015877, 25.041203438015877, 12.891644050495675, 12.891644050495675, 25.041203438015877, 16.24761642898487, 28.987872936988538, 16.24761642898487, 33.08637700945763, 12.891644050495675]
# attractiveness = array([-25.04120344, -25.04120344, -12.89164405, -12.89164405,
#        -25.04120344, -16.24761643, -28.98787294, -16.24761643,
#        -33.08637701, -12.89164405])
# len(parent_costs) = 10
# crossover_kwargs = {'k': 4, 'inversion_p': 0.3}
# __fix_tsp chromosome = [0, 4, 3, 8, 4, 1, 6, 7, 5, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 4, 3, 8, 4, 1, 6, 7, 5, 0]
# find invalid transitions solution = [0, 4, 3, 8, 2, 1, 6, 7, 5, 0]
# __fix_tsp chromosome = [0, 3, 6, 2, 5, 8, 7, 2, 1, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 6, 2, 5, 8, 7, 2, 1, 0]
# find invalid transitions solution = [0, 3, 6, 0, 5, 8, 7, 2, 1, 4]
# __fix_tsp chromosome = [0, 4, 6, 1, 2, 5, 7, 1, 3, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 4, 6, 1, 2, 5, 7, 1, 3, 0]
# find invalid transitions solution = [0, 4, 6, 8, 2, 5, 7, 1, 3, 0]
# __fix_tsp chromosome = [4, 7, 0, 8, 2, 3, 8, 5, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 0, 8, 2, 3, 8, 5, 6, 0]
# find invalid transitions solution = [0, 7, 8, 1, 2, 3, 4, 5, 6, 0]
# __fix_tsp chromosome = [0, 1, 3, 4, 4, 7, 5, 2, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 1, 3, 4, 4, 7, 5, 2, 6, 0]
# find invalid transitions solution = [0, 1, 3, 4, 8, 7, 5, 2, 6, 0]
# __fix_tsp chromosome = [0, 3, 8, 1, 8, 5, 7, 2, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 8, 1, 8, 5, 7, 2, 6, 0]
# find invalid transitions solution = [0, 3, 4, 1, 8, 5, 7, 2, 6, 0]
# ...
# __fix_tsp chromosome = [0, 7, 8, 1, 2, 5, 3, 3, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 8, 1, 2, 5, 3, 3, 6, 0]
# find invalid transitions solution = [0, 7, 8, 1, 2, 5, 4, 3, 6, 0]
# __fix_tsp chromosome = [0, 7, 1, 8, 2, 4, 4, 5, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 1, 8, 2, 4, 4, 5, 6, 0]
# find invalid transitions solution = [0, 7, 1, 8, 2, 4, 3, 5, 6, 0]
# len(next_gen_costs) = 10, len(next_gen) = 10
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# i = 24----------------------------------------
# in while: len(costs) = 10, len(population) = 10
# costs = [12.891644050495675, 26.735827188021972, 17.475040558814257, 12.891644050495675, 12.891644050495675, 33.08637700945763, 12.891644050495675, 22.200217432100896, 16.24761642898487, 25.400387227497507]
# attractiveness = array([-12.89164405, -26.73582719, -17.47504056, -12.89164405,
#        -12.89164405, -33.08637701, -12.89164405, -22.20021743,
#        -16.24761643, -25.40038723])
# len(parent_costs) = 10
# crossover_kwargs = {'k': 4, 'inversion_p': 0.3}
# __fix_tsp chromosome = [0, 1, 3, 8, 1, 7, 5, 5, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 1, 3, 8, 1, 7, 5, 5, 6, 0]
# find invalid transitions solution = [0, 1, 3, 8, 5, 7, 2, 4, 6, 0]
# __fix_tsp chromosome = [0, 7, 2, 4, 2, 6, 3, 4, 8, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 2, 4, 2, 6, 3, 4, 8, 0]
# find invalid transitions solution = [0, 7, 5, 4, 1, 6, 3, 2, 8, 0]
# __fix_tsp chromosome = [3, 7, 5, 8, 2, 5, 4, 0, 2, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 5, 8, 2, 5, 4, 0, 2, 0]
# find invalid transitions solution = [0, 7, 5, 8, 6, 3, 4, 1, 2, 0]
# __fix_tsp chromosome = [0, 7, 8, 1, 4, 1, 6, 3, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 8, 1, 4, 1, 6, 3, 6, 0]
# find invalid transitions solution = [0, 7, 8, 5, 4, 1, 2, 3, 6, 0]
# __fix_tsp chromosome = [3, 1, 1, 5, 8, 0, 5, 3, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 1, 1, 5, 8, 0, 5, 3, 6, 0]
# find invalid transitions solution = [0, 1, 2, 5, 8, 0, 4, 3, 6, 0]
# __fix_tsp chromosome = [7, 7, 0, 4, 6, 4, 2, 8, 2, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 0, 4, 6, 4, 2, 8, 2, 0]
# find invalid transitions solution = [0, 7, 5, 4, 6, 3, 0, 8, 2, 0]
# __fix_tsp chromosome = [0, 0, 1, 3, 8, 5, 4, 4, 8, 6]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 0, 1, 3, 8, 5, 4, 4, 8, 0]
# find invalid transitions solution = [0, 4, 1, 3, 6, 5, 8, 7, 2, 0]
# __fix_tsp chromosome = [7, 0, 3, 2, 2, 5, 7, 1, 0, 6]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 0, 3, 2, 2, 5, 7, 1, 0, 0]
# find invalid transitions solution = [0, 4, 3, 6, 0, 5, 7, 1, 2, 8]
# __fix_tsp chromosome = [8, 7, 1, 3, 2, 4, 5, 0, 0, 6]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 1, 3, 2, 4, 5, 0, 0, 0]
# find invalid transitions solution = [0, 7, 1, 3, 2, 4, 5, 0, 6, 0]
# __fix_tsp chromosome = [0, 7, 2, 1, 8, 5, 4, 3, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 2, 1, 8, 5, 4, 3, 6, 0]
# find invalid transitions solution = [0, 7, 2, 1, 8, 5, 4, 3, 6, 0]
# len(next_gen_costs) = 10, len(next_gen) = 10
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# i = 25----------------------------------------
# in while: len(costs) = 10, len(population) = 10
# costs = [12.891644050495675, 12.891644050495675, 24.121974350512026, 12.891644050495675, 25.400387227497507, 23.87362589912844, 26.67606825053815, 26.735827188021972, 18.57951803168039, 22.200217432100896]
# attractiveness = array([-12.89164405, -12.89164405, -24.12197435, -12.89164405,
#        -25.40038723, -23.8736259 , -26.67606825, -26.73582719,
#        -18.57951803, -22.20021743])
# len(parent_costs) = 10
# crossover_kwargs = {'k': 4, 'inversion_p': 0.3}
# __fix_tsp chromosome = [0, 8, 7, 8, 6, 3, 3, 2, 0, 2]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 8, 7, 8, 6, 3, 3, 2, 0, 0]
# find invalid transitions solution = [0, 3, 7, 8, 6, 4, 1, 2, 0, 5]
# __fix_tsp chromosome = [0, 7, 5, 4, 1, 5, 4, 1, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 5, 4, 1, 5, 4, 1, 6, 0]
# find invalid transitions solution = [0, 7, 8, 5, 4, 1, 2, 3, 6, 0]
# __fix_tsp chromosome = [3, 0, 7, 6, 3, 8, 4, 2, 8, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 0, 7, 6, 3, 8, 4, 2, 8, 0]
# find invalid transitions solution = [0, 1, 7, 8, 3, 4, 5, 2, 0, 0]
# __fix_tsp chromosome = [0, 1, 2, 1, 5, 7, 5, 4, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 1, 2, 1, 5, 7, 5, 4, 6, 0]
# find invalid transitions solution = [0, 3, 2, 5, 8, 7, 1, 4, 6, 0]
# __fix_tsp chromosome = [0, 1, 8, 7, 2, 5, 4, 3, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 1, 8, 7, 2, 5, 4, 3, 6, 0]
# find invalid transitions solution = [0, 1, 8, 7, 2, 5, 4, 3, 6, 0]
# __fix_tsp chromosome = [0, 7, 8, 1, 2, 5, 4, 3, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 8, 1, 2, 5, 4, 3, 6, 0]
# find invalid transitions solution = [0, 7, 8, 1, 2, 5, 4, 3, 6, 0]
# __fix_tsp chromosome = [0, 6, 3, 4, 5, 5, 1, 2, 4, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 6, 3, 4, 5, 5, 1, 2, 4, 0]
# find invalid transitions solution = [0, 6, 3, 4, 7, 8, 1, 2, 5, 0]
# __fix_tsp chromosome = [0, 7, 0, 1, 7, 8, 6, 8, 2, 3]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 0, 1, 7, 8, 6, 8, 2, 0]
# find invalid transitions solution = [0, 3, 4, 1, 5, 8, 6, 7, 2, 0]
# __fix_tsp chromosome = [0, 4, 8, 1, 2, 5, 8, 3, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 4, 8, 1, 2, 5, 8, 3, 6, 0]
# find invalid transitions solution = [0, 4, 7, 1, 2, 5, 8, 3, 6, 0]
# __fix_tsp chromosome = [0, 7, 3, 1, 6, 4, 5, 7, 2, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 3, 1, 6, 4, 5, 7, 2, 0]
# find invalid transitions solution = [0, 1, 3, 8, 6, 4, 5, 7, 2, 0]
# len(next_gen_costs) = 10, len(next_gen) = 10
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# i = 26----------------------------------------
# in while: len(costs) = 10, len(population) = 10
# costs = [12.891644050495675, 12.891644050495675, 12.891644050495675, 16.57597023626065, 25.400387227497507, 18.57951803168039, 24.121974350512026, 22.772197580910408, 26.735827188021972, 26.67606825053815]
# attractiveness = array([-12.89164405, -12.89164405, -12.89164405, -16.57597024,
#        -25.40038723, -18.57951803, -24.12197435, -22.77219758,
#        -26.73582719, -26.67606825])
# len(parent_costs) = 10
# crossover_kwargs = {'k': 4, 'inversion_p': 0.3}
# __fix_tsp chromosome = [0, 6, 5, 8, 4, 5, 4, 1, 2, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 6, 5, 8, 4, 5, 4, 1, 2, 0]
# find invalid transitions solution = [0, 6, 3, 8, 5, 4, 7, 1, 2, 0]
# __fix_tsp chromosome = [2, 7, 7, 1, 0, 6, 3, 8, 3, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 7, 1, 0, 6, 3, 8, 3, 0]
# find invalid transitions solution = [0, 3, 4, 1, 2, 6, 7, 8, 5, 0]
# __fix_tsp chromosome = [0, 7, 8, 1, 4, 1, 2, 3, 4, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 8, 1, 4, 1, 2, 3, 4, 0]
# find invalid transitions solution = [0, 7, 8, 5, 4, 1, 2, 3, 6, 0]
# __fix_tsp chromosome = [5, 7, 3, 2, 6, 5, 0, 8, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 3, 2, 6, 5, 0, 8, 6, 0]
# find invalid transitions solution = [0, 7, 3, 2, 1, 5, 0, 8, 6, 0]
# __fix_tsp chromosome = [0, 8, 7, 1, 5, 4, 4, 3, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 8, 7, 1, 5, 4, 4, 3, 6, 0]
# find invalid transitions solution = [0, 8, 7, 1, 5, 4, 2, 3, 6, 0]
# __fix_tsp chromosome = [0, 7, 8, 2, 1, 5, 2, 3, 0, 6]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 8, 2, 1, 5, 2, 3, 0, 0]
# find invalid transitions solution = [0, 7, 8, 6, 1, 5, 4, 3, 0, 2]
# __fix_tsp chromosome = [1, 0, 2, 5, 8, 4, 5, 4, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 0, 2, 5, 8, 4, 5, 4, 6, 0]
# find invalid transitions solution = [0, 3, 2, 5, 8, 7, 1, 4, 6, 0]
# __fix_tsp chromosome = [0, 3, 3, 8, 6, 7, 1, 7, 2, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 3, 8, 6, 7, 1, 7, 2, 0]
# find invalid transitions solution = [0, 3, 4, 8, 6, 7, 1, 5, 2, 0]
# __fix_tsp chromosome = [0, 7, 8, 1, 2, 3, 4, 3, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 8, 1, 2, 3, 4, 3, 6, 0]
# find invalid transitions solution = [0, 7, 8, 1, 2, 5, 4, 3, 6, 0]
# __fix_tsp chromosome = [0, 7, 8, 1, 2, 5, 4, 5, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 8, 1, 2, 5, 4, 5, 6, 0]
# find invalid transitions solution = [0, 7, 8, 1, 2, 5, 4, 3, 6, 0]
# len(next_gen_costs) = 10, len(next_gen) = 10
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# i = 27----------------------------------------
# in while: len(costs) = 10, len(population) = 10
# costs = [12.891644050495675, 16.57597023626065, 25.400387227497507, 12.891644050495675, 22.772197580910408, 24.121974350512026, 18.57951803168039, 12.891644050495675, 16.57597023626065, 12.891644050495675]
# attractiveness = array([-12.89164405, -16.57597024, -25.40038723, -12.89164405,
#        -22.77219758, -24.12197435, -18.57951803, -12.89164405,
#        -16.57597024, -12.89164405])
# len(parent_costs) = 10
# crossover_kwargs = {'k': 4, 'inversion_p': 0.3}
# __fix_tsp chromosome = [0, 4, 3, 5, 2, 7, 8, 1, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 4, 3, 5, 2, 7, 8, 1, 6, 0]
# __fix_tsp chromosome = [0, 6, 1, 8, 7, 2, 5, 3, 4, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 6, 1, 8, 7, 2, 5, 3, 4, 0]
# __fix_tsp chromosome = [0, 7, 8, 1, 2, 5, 4, 3, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 8, 1, 2, 5, 4, 3, 6, 0]
# find invalid transitions solution = [0, 7, 8, 1, 2, 5, 4, 3, 6, 0]
# __fix_tsp chromosome = [6, 3, 2, 2, 1, 1, 7, 3, 0, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 3, 2, 2, 1, 1, 7, 3, 0, 0]
# find invalid transitions solution = [0, 3, 4, 1, 2, 5, 7, 8, 0, 6]
# __fix_tsp chromosome = [0, 8, 5, 8, 6, 5, 4, 7, 0, 4]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 8, 5, 8, 6, 5, 4, 7, 0, 0]
# find invalid transitions solution = [0, 3, 0, 1, 6, 8, 4, 7, 5, 2]
# __fix_tsp chromosome = [0, 1, 7, 3, 2, 1, 6, 3, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 1, 7, 3, 2, 1, 6, 3, 6, 0]
# find invalid transitions solution = [0, 3, 7, 8, 2, 5, 4, 1, 6, 0]
# __fix_tsp chromosome = [0, 7, 8, 5, 4, 5, 4, 0, 2, 8]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 8, 5, 4, 5, 4, 0, 2, 0]
# find invalid transitions solution = [0, 7, 8, 5, 4, 1, 3, 6, 2, 0]
# __fix_tsp chromosome = [2, 7, 3, 8, 6, 0, 1, 4, 3, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 3, 8, 6, 0, 1, 4, 3, 0]
# find invalid transitions solution = [0, 7, 5, 8, 6, 0, 1, 4, 3, 0]
# __fix_tsp chromosome = [0, 1, 6, 5, 8, 4, 7, 5, 0, 2]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 1, 6, 5, 8, 4, 7, 5, 0, 0]
# find invalid transitions solution = [0, 1, 6, 3, 8, 5, 7, 2, 0, 4]
# __fix_tsp chromosome = [0, 7, 8, 5, 3, 5, 2, 2, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 8, 5, 3, 5, 2, 2, 6, 0]
# find invalid transitions solution = [0, 7, 8, 5, 3, 4, 1, 2, 6, 0]
# __fix_tsp chromosome = [0, 1, 8, 0, 4, 1, 7, 3, 6, 4]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 1, 8, 0, 4, 1, 7, 3, 6, 0]
# find invalid transitions solution = [0, 1, 8, 0, 4, 5, 7, 3, 6, 0]
# len(next_gen_costs) = 10, len(next_gen) = 10
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# i = 28----------------------------------------
# in while: len(costs) = 10, len(population) = 10
# costs = [12.891644050495675, 16.24761642898487, 12.891644050495675, 12.891644050495675, 12.891644050495675, 16.57597023626065, 18.57951803168039, 25.400387227497507, 12.891644050495675, 12.891644050495675]
# attractiveness = array([-12.89164405, -16.24761643, -12.89164405, -12.89164405,
#        -12.89164405, -16.57597024, -18.57951803, -25.40038723,
#        -12.89164405, -12.89164405])
# len(parent_costs) = 10
# crossover_kwargs = {'k': 4, 'inversion_p': 0.3}
# __fix_tsp chromosome = [2, 5, 8, 1, 4, 7, 3, 0, 2, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 5, 8, 1, 4, 7, 3, 0, 2, 0]
# find invalid transitions solution = [0, 5, 8, 1, 4, 7, 3, 0, 2, 0]
# __fix_tsp chromosome = [0, 5, 3, 7, 1, 8, 6, 4, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 5, 3, 7, 1, 8, 6, 4, 6, 0]
# find invalid transitions solution = [0, 5, 3, 6, 1, 8, 7, 4, 2, 0]
# __fix_tsp chromosome = [0, 4, 3, 1, 2, 5, 7, 1, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 4, 3, 1, 2, 5, 7, 1, 6, 0]
# find invalid transitions solution = [0, 4, 3, 8, 2, 5, 7, 1, 6, 0]
# __fix_tsp chromosome = [0, 7, 8, 8, 2, 3, 4, 5, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 8, 8, 2, 3, 4, 5, 6, 0]
# find invalid transitions solution = [0, 7, 8, 1, 2, 3, 4, 5, 6, 0]
# __fix_tsp chromosome = [0, 7, 8, 8, 5, 5, 4, 3, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 8, 8, 5, 5, 4, 3, 6, 0]
# find invalid transitions solution = [0, 7, 8, 5, 2, 1, 4, 3, 6, 0]
# __fix_tsp chromosome = [0, 2, 3, 2, 1, 7, 1, 4, 0, 6]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 2, 3, 2, 1, 7, 1, 4, 0, 0]
# find invalid transitions solution = [0, 1, 3, 6, 0, 7, 8, 4, 5, 2]
# __fix_tsp chromosome = [1, 7, 8, 0, 2, 5, 4, 0, 6, 3]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 8, 0, 2, 5, 4, 0, 6, 0]
# find invalid transitions solution = [0, 7, 8, 0, 2, 5, 4, 1, 6, 0]
# __fix_tsp chromosome = [0, 7, 8, 1, 2, 5, 4, 0, 6, 3]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 7, 8, 1, 2, 5, 4, 0, 6, 0]
# find invalid transitions solution = [0, 7, 8, 1, 2, 5, 4, 3, 6, 0]
# __fix_tsp chromosome = [0, 8, 7, 1, 5, 2, 4, 3, 6, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 8, 7, 1, 5, 2, 4, 3, 6, 0]
# find invalid transitions solution = [0, 8, 7, 1, 5, 2, 4, 3, 6, 0]
# __fix_tsp chromosome = [8, 1, 0, 7, 5, 2, 6, 3, 4, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 1, 0, 7, 5, 2, 6, 3, 4, 0]
# __fix_tsp chromosome = [0, 4, 3, 6, 2, 5, 7, 8, 1, 0]
# initial_vx = 0(<class 'int'>)
# find invalid transitions solution = [0, 4, 3, 6, 2, 5, 7, 8, 1, 0]
# ERROR - ix = 9, len(parent_costs) = 10, fail_ixs = [9]
# C:\Users\obszansk\my\bachelor-thesis-project\.venv\lib\site-packages\numpy\core\_methods.py:229: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# end_reason: exception
# best_sol: []
# experiment_config_path: test_experiment_config.json
# end_iter: 28
# exception: ValueError: not enough values to unpack (expected 2, got 1)
# traceback:   File "C:\Users\obszansk\my\bachelor-thesis-project\bin\refactored_experiment.py", line 73, in experiment_tsp
#     for i, (next_gen, next_gen_data, rng) in enumerate(stepper):
#
#   File "C:\Users\obszansk\my\bachelor-thesis-project\libs\optimizers\algorithms\genetic\steppers\tsp.py", line 112, in genetic_stepper_tsp
#     checked_offspring = replace_invalid_offspring(
#
#   File "C:\Users\obszansk\my\bachelor-thesis-project\libs\optimizers\algorithms\genetic\population\natural_selection.py", line 141, in replace_invalid_offspring
#     raise e
#
#   File "C:\Users\obszansk\my\bachelor-thesis-project\libs\optimizers\algorithms\genetic\population\natural_selection.py", line 138, in replace_invalid_offspring
#     p1c, p2c = parent_costs[ix : ix + 2]
